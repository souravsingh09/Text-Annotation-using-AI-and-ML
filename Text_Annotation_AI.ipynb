# %%
# nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/souravsingh/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# import all the necessary library for the operation.
import pandas as pd
import unidecode
import nltk
import re
import pandas as pd
import traceback
from nltk.corpus import stopwords
import json
import re

# %%
# Opening JSON file
f = open('/Users/souravsingh/Desktop/response.json',)

# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
dataList = []
for i in range(len(data)):
    txt = re.sub('<[A-Za-z\/][^>]*>', '', data[i]['indications'])
    dataList.append(txt)

# %%
unwanted = []
for i in range(len(dataList)):
    if len(dataList[i]) == 0:
        unwanted.append(i)

# %%
print(len(dataList))
for ele in sorted(unwanted, reverse = True):
    del dataList[ele]

print(len(dataList))
# Out:
# 9473
# 9173

# %%
dataList[1]
# Out:
# '1 INDICATIONS AND USAGETherapy with lipid-altering agents should be only one component of multiple risk factor intervention in individuals at significantly increased risk for atherosclerotic vascular disease due to hypercholesterolemia. Drug therapy is recommended as an adjunct to diet when the response to a diet restricted in saturated fat and cholesterol and other nonpharmacologic measures alone has been inadequate. In patients with CHD or multiple risk factors for CHD, atorvastatin calcium tablets can be started simultaneously with diet.1.1 Prevention of Cardiovascular Disease in AdultsIn adult patients without clinically evident coronary heart disease, but with multiple risk factors for coronary heart disease such as age, smoking, hypertension, low HDL-C, or a family history of early coronary heart disease, atorvastatin calcium tablets are indicated to:•Reduce the risk of myocardial infarction          •Reduce the risk of stroke          •Reduce the risk for revascularization procedures and angina          In adult patients with type 2 diabetes, and without clinically evident coronary heart disease, but with multiple risk factors for coronary heart disease such as retinopathy, albuminuria, smoking, or hypertension, atorvastatin calcium tablets are indicated to:•Reduce the risk of myocardial infarction          •Reduce the risk of stroke          In adult patients with clinically evident coronary heart disease, atorvastatin calcium tablets are indicated to:•Reduce the risk of non-fatal myocardial infarction          •Reduce the risk of fatal and non-fatal stroke          •Reduce the risk for revascularization procedures          •Reduce the risk of hospitalization for CHF          •Reduce the risk of angina          1.2 HyperlipidemiaAtorvastatin calcium tablets are indicated•As an adjunct to diet to reduce elevated total-C, LDL-C, apo B, and TG levels and to increase HDL-C in adult patients with primary hypercholesterolemia (heterozygous familial and nonfamilial) and mixed dyslipidemia (    Fredrickson Types IIa and IIb);   •As an adjunct to diet for the treatment of adult patients with elevated serum TG levels (    Fredrickson Type IV);   •For the treatment of adult patients with primary dysbetalipoproteinemia (    Fredrickson Type III) who do not respond adequately to diet;   •To reduce total-C and LDL-C in patients with homozygous familial hypercholesterolemia (HoFH) as an adjunct to other lipid-lowering treatments (e.g., LDL apheresis) or if such treatments are unavailable;•As an adjunct to diet to reduce total-C, LDL-C, and apo B levels in pediatric patients, 10 to 17 years of age, with heterozygous familial hypercholesterolemia (HeFH) if after an adequate trial of diet therapy the following findings are present: \t    •LDL-C remains = 190 mg/dL or•LDL-C remains = 160 mg/dL and:•there is a positive family history of premature cardiovascular disease or•two or more other CVD risk factors are present in the pediatric patient1.3 Limitations of UseAtorvastatin calcium tablets have not been studied in conditions where the major lipoprotein abnormality is elevation of chylomicrons (   Fredrickson Types I and V).  '

# %%
clean_Text = []
## read each element and clean the text
subst = ""
for text in dataList:
    # remove 1.1 headings and similar
    regex = r"(INDICATIONS AND USAGE )"
    text = re.sub(regex, subst, text, 0, re.MULTILINE)
    
    text = re.sub('INDICATIONS AND USAGE', ' ', text)
    
    regex = r"(\d\S\d+(.*?),,)"
    text = re.sub(regex, subst, text, 0, re.MULTILINE)
    
    ### renove ,,,,, from end of every element
    regex = r"(\S\,,,+)"
    text = re.sub(regex, subst, text, 0, re.MULTILINE)
    
    ### remove trademark 
    regex = r"(®)"
    text = re.sub(regex, subst, text, 0, re.MULTILINE)
    
    ### remove "" in continuation 
    regex = r"(\"\")"
    text = re.sub(regex, '" ', text, 0, re.MULTILINE)
    
    ## remove consecuitve commas
    regex = r"(\,\,)"
    text = re.sub(regex, ', ', text, 0, re.MULTILINE)
    
    ## 
    regex = r"(\*)"
    text = re.sub(regex, ', ', text, 0, re.MULTILINE)
    
    text = re.sub(r'\n', '', text)
    
    ## remove extra spaces
    text = re.sub(' +', ' ', text)

    word = unidecode.unidecode(text)
    
    clean_Text.append(word)

# %%
len(clean_Text)
# Out:
# 9173

# %%
clean_Text = clean_Text[:5000]
print(len(clean_Text))
# Out:
# 5000

# %% [markdown]
# # Drugs Name

# %%
drug_df = pd.read_csv('/Users/souravsingh/Documents/NER/Annotation_Data/product.csv')

# %%
drug_df.head()
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0002-0800_662164fd-5ea0-4a08-bfd1-6b08bdd73342  0002-0800
# 1  0002-1200_480fceef-6596-4478-97de-677c155506b3  0002-1200
# 2  0002-1210_151a431b-f07b-4959-b6fa-c41ff80364c8  0002-1210
# 3  0002-1433_ac6e0e9f-724c-4c78-823c-cea3ca6c0727  0002-1433
# 4  0002-1434_ac6e0e9f-724c-4c78-823c-cea3ca6c0727  0002-1434
#
#            PRODUCTTYPENAME  PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0           HUMAN OTC DRUG  Sterile Diluent                   NaN
# 1  HUMAN PRESCRIPTION DRUG           Amyvid                   NaN
# 2  HUMAN PRESCRIPTION DRUG           TAUVID                   NaN
# 3  HUMAN PRESCRIPTION DRUG        Trulicity                   NaN
# 4  HUMAN PRESCRIPTION DRUG        Trulicity                   NaN
#
#   NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 0            diluent  INJECTION, SOLUTION  SUBCUTANEOUS            19870710
# 1   Florbetapir F 18  INJECTION, SOLUTION   INTRAVENOUS            20120601
# 2  Flortaucipir F-18  INJECTION, SOLUTION   INTRAVENOUS            20200528
# 3        Dulaglutide  INJECTION, SOLUTION  SUBCUTANEOUS            20140918
# 4        Dulaglutide  INJECTION, SOLUTION  SUBCUTANEOUS            20140918
#
#    ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 0               NaN                   BLA         BLA018781
# 1               NaN                   NDA         NDA202008
# 2               NaN                   NDA         NDA212123
# 3               NaN                   BLA         BLA125469
# 4               NaN                   BLA         BLA125469
#
#              LABELERNAME      SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 0  Eli Lilly and Company              WATER                         1
# 1  Eli Lilly and Company   FLORBETAPIR F-18                        51
# 2  Eli Lilly and Company  FLORTAUCIPIR F-18                        51
# 3  Eli Lilly and Company        DULAGLUTIDE                      0.75
# 4  Eli Lilly and Company        DULAGLUTIDE                       1.5
#
#   ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 0              mL/mL                                                NaN
# 1             mCi/mL  Radioactive Diagnostic Agent [EPC],Positron Em...
# 2             mCi/mL                                                NaN
# 3            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
# 4            mg/.5mL  GLP-1 Receptor Agonist [EPC],Glucagon-Like Pep...
#
#   DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 0         NaN                N                        20211231.0
# 1         NaN                N                        20211231.0
# 2         NaN                N                        20211231.0
# 3         NaN                N                        20221231.0
# 4         NaN                N                        20221231.0

# %%
## keep only human drug names and validate it
drug_df.drop(drug_df[ (drug_df['PRODUCTTYPENAME'] != 'HUMAN PRESCRIPTION DRUG')].index, axis=0, inplace=True)
drug_df.reset_index(drop=True,inplace=True)
print(drug_df['PRODUCTTYPENAME'].value_counts())
# Out:
# HUMAN PRESCRIPTION DRUG    49636
# Name: PRODUCTTYPENAME, dtype: int64

# %%
#remove NAN values from drug names
drug_df.dropna(subset = ['NONPROPRIETARYNAME','PROPRIETARYNAME'], inplace=True)
drug_df.reset_index(drop=True,inplace=True)

# %%
## paracetamol 
drug_PROPRIETARYNAME_list = drug_df['PROPRIETARYNAME'].to_list()
## actual drug name
drug_NONPROPRIETARYNAME_list = drug_df['NONPROPRIETARYNAME'].to_list()

# %%
#create the list of all drug names
drugList =[]
drugList.extend(drug_PROPRIETARYNAME_list)
drugList.extend(drug_NONPROPRIETARYNAME_list)

# %%
print('Length of drug list Before removing duplicates : {}'.format(len(drugList)))
# remove duplicate name by creating set
drugList = map(lambda x: x.lower(), drugList)
drugList =set(drugList)

# drugList = list(map(lambda x: x.lower(), drug_list))
drugList = list(drugList)
print('Length of drug list After removing duplicates : {}'.format(len(drugList)))
# Out:
# Length of drug list Before removing duplicates : 99264
# Length of drug list After removing duplicates : 7304

# %%
filtered_words = list(filter(lambda word: word not in stopwords.words('english'), drugList))

# %%
len(filtered_words)
drugList = filtered_words

# %%
drugList.sort(key=len, reverse=True)

# %%
drugList
# Out:
# ['agaricus muscarius, coccus cacti, conium maculatum, lycopodium clavatum, phosphorus, aluminium metallicum, antimonium crudum, argentum metallicum, arsenicum album, aurum metallicum, baryta carbonica, beryllium metallicum, bismuthum metallicum, boron, bromium, cadmium metallicum cerium metallicum, cesium chloride, chromium, cobaltum metallicum, cuprum metallicum, dysprosium metallicum, erbium metallicum, europium metallicum, ferrum metallicum, gadolinium metallicum, germanium sesquioxide, holmium metallicum,',
#  'feliscatushair,bostaurushair,bostaurusskin,gallusgallusfeather,canislupusfamiliarisskin,canisfamiliarishair,anasplatyrhynchosfeather,anseranserfeather,caviaporcellushair,caviaporcellusskin,mesocricetusauratushair,mesocricetusauratusskin,susscrofahair,susscrofaskin,equuscaballushair,equuscaballusdander,musmusculushair,musmusculuasskin,oryctolaguscuniculusskin,oryctolaguscuniculushair,ovisarieswhole,meleagrisgallopavofeather,arsenictrioxide,blattaorientalis,strychnosnux-vomicaseed,phosphorus,pulsatilla,sulfur',
#  'passiflora incarnata, chamomilla, valeriana officinalis, fucus officinalis, agnus castus, kali phosphoricum, natrum muriaticum, nux vomica, phytolacca decandra, chelidonium majus, lycopodium clavatum, pituitarum posterium (bovine), adrenocorticotrophin, thyroidinum (bovine), thyroidinum (ovine), calcarea carbonica, carbo vegetabilis, magnesia phosphorica, natrum phosphoricum, ubidecarenonum, graphites, hypophysis suis, hypothalamus (bovine), placenta totalis suis, argentum nitricum, berberis vulgaris,',
#  'geranium robertianum, nasturtium aquaticum, aloe, myosotis arvensis, scrophularia nodosa, teucrium scorodonia, apis mellifica, equisetum hyemale, fumaria officinalis, natrum sulphuricum, phytolacca decandra, pinus sylvestris, veronica officinalis, gentiana lutea, juglans regia, sarsaparilla (smilax regelii) baryta carbonica, hepar sulphuris calcareum, mercurius cyanatus, ferrum iodatum, aranea diadema, calcarea phosphorica, parathyroid gland (bovine), thymus (suis), thyroidinum (suis)',
#  'baptisia tinctoria, echinacea (angustifolia), lobelia inflata, lomatium dissectum, hydrastis canadensis, lung (suis), phytolacca decandra, symphytum officinale, aconitum napellus, arsenicum album, belladonna, bryonia (alba), causticum, eupatorium perfoliatum, ferrum phosphoricum, gelsemium sempervirens, hypericum perforatum, kali carbonicum, lachesis mutus, natrum sulphuricum, phosphorus, pulsatilla (pratensis), rhus tox, silicea, sulphur, pyrogenium',
#  'solidago virgaurea, asparagus officinalis, juniperus communis, sabal serrulata, uva-ursi, berberis vulgaris, equisetum arvense, urtica dioica, rubia tinctorum, staphysagria, cantharis, fagus sylvatica, flos, glandula suprarenalis suis, hepar sulphuris calcareum, kidney (suis), larix decidua, flos, manganum metallicum, mimulus guttatus, flos, nitricum acidum, rhus aromatica, silicea, ulex europaeus, flos, benzoicum acidum, cobaltum metallicum',
#  'alfalfa, avena sativa, citrus limonum, glycyrrhiza glabra, uva-ursi, taraxacum officinale, galium aparine, schisandra chinensis, solid ago virgaurea, tabacum, tylophora asthmatica, berberis vulgaris, chelidonium majus, hepar suis, intestine (suis), kidney (suis), lung (suis), lymph node (suis), magnesium gluconate, nux vomica, potassium gluconate, zincum gluconicum, sarcolacticum acidum, lacticum acidum',
#  'leucovorin, folic acid, levomefolate magnesium, ferrous cysteine glycinate, 1,2-docosahexanoyl-sn-glycero-3-phosphoserine calcium, 1,2-icosapentoyl-sn-glycero-3-phosphoserine calcium, phosphatidyl serine, pyridoxal 5-phosphate, flavin adenine dinucleotide, nadh, cobamamide, cocarboxylase (thiamine pyrophosphate), magnesium ascorbate, zinc ascorbate, magnesium l-threonate and betaine',
#  'araneus diadematus, tribasic calcium phosphate, equisetum hyemale, ferrous iodide,fumaria officinalis flowering top, gentiana lutea root, geranium robertianum, myosotis arvensis, nasturtium officinale, sodium sulfate, pinus sylvestris leafy twig,smilax regelii root, scrophularia nodosa, teucrium scorodonia flowering top, thyroid, unspecified andveronica officinalis flowering top',
#  'levomefolate magnesium, leucovorin, folic acid, ferrous cysteine glycinate, magnesium ascorbate, zinc ascorbate, cocarboxylase, flavin adenine dinucleotide, nadh, pyridoxal phosphate anhydrous, cobamamide, betaine, magnesium l-threonate, 1,2-docosahexanoyl-sn-glycero-3-phosphoserine calcium, 1,2-icosapentoyl-sn-glycero-3-phosphoserine calcium, and phosphatidyl serine',
#  'baptisia tinctoria, echinacea (angustifolia), hydrastis canadensis, borrelia burgdorferi nosode, babesia microti, ehrlichia nosode (canine), encephalitis nosode, meningococcus nosode, hepatitis b nosode, arsenicum album, bryonia (alba), chelidonium majus, colchicum autumnale, kalmia latifolia, ledum palustre, lycopodium clavatum, phosphorus, rhus tox',
#  'alfalfa, laminaria digitata, symphytum officinale, ascorbic acid, melatonin, calcarea carbonica, cuprum metallicum, ferrum metallicum, iodium, manganum aceticum, silicea, phosphorus, magnetis polus arcticus, magnetis polus australis, x-ray, agate, quartz, carbon dioxide, aconitum napellus, arsenicum album, gaertner bacillus (bach), kali carbonicum',
#  'chamomilla, cimicifuga racemosa, helonias dioica, mentha piperita, senna (cassia angustifolia), valeriana officinalis, viola odorata, agnus castus, ledum palustre, lilium tigrinum, staphysagria, crocus sativus, hydrastis canadensis, cinchona officinalis, convallaria majalis, cyclamen europaeum, cinnamomum, murex purpurea, naja tripudians',
#  'aconitum napellus, aranea diadema, arnica montana, asclepias vincetoxicum, baptisia tinctoria, bryonia alba, echinacea angustifolia, equisetum hyemale, eupatorium perforliatum, gelsemium sempervirens, hepar sulphuris calcareum, juglans regia, phytolacca decandra, sanguinaria canadensis, sarsaparilla, sulphur, zincum metallicum',
#  '.beta.-carotene, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, 5-methyltetrahydrofolic acid, calcium formate, ferrous asparto glycinate, cyanocobalamin, biotin, potassium iodide, magnesium oxide, zinc oxide and cupric oxide',
#  'arnica montana root, atropa belladonna, calendula officinalis flowering top, matricaria recutita, achillea millefolium, calcium sulfide, comfrey root, aconitum napellus, bellis perennis, mercurius solubilis, hypericum perforatum, echinacea, unspecified, echinacea purpurea and hamamelis virginiana root bark/stem bark',
#  'aconitum napellus, arnica montana root, atropa belladonna, bellis perennis, calendula officinalis flowering top, matricaria recutita, echinacea, unspecified, echinacea purpurea, hamamelis virginiana root bark/stem bark, calcium sulfide, hypericum perforatum, mercurius solubilis, achillea millefolium and comfrey root',
#  'vitamin a acetate, ascorbic acid, cholecalciferol, alpha-tocopherol acetate, dl, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, cyanocobalamin, biotin, calcium pantothenate, calcium carbonate, ferrous fumarate, potassium iodide, magnesium oxide, zinc oxide and cupric oxide',
#  'sodium ascorbate, cholecalciferol, di-alpha-tocopheryl acetate, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hcl, folic acid, cyanocobalamin, calcium formate, calcium carbonate, ferrous (ii) bis-glycinate chelate, potassium iodide, zinc oxide, choline bitartrate, with doconexent and icosapent',
#  'aconitum nap, apis mel, arnica, arsenicum alb, belladonna, bellis, bryonia, calendula, chamomilla, cistus canadensis, clematis erecta, ferrum phos, histaminum, hypericum, ignatia, impatiens glan flos, ornithogalum, passiflora, phosphorus, prunus cerasifera, rhus tox, sulphur, symphytum, vertarum alb',
#  'pediculus capitis, thyroidinum (suis), baryta carbonica, borax, calcarea carbonica, cinchona officinalis, glandula suprarenalis suis, hydrofluoricum acidum, mercurius solubilis, mezereum, natrum muriaticum, phosphorus, pulsatilla (pratensis), sepia, silicea, sulphur, thuja occidentalis, vinca minor',
#  'glycerin, isoleucine, leucine, lysine, methionine, phenylalanine, threonine, tryptophan, valine, alanine, glycine, arginine, histidine, proline, serine, cysteine, sodium acetate, magnesium acetate, calcium acetate, sodium chloride, potassium chloride, phosphoric acid, and potassium metabisulfite',
#  'arnica montana, cinnamomum, dulcamara, funiculus umbilicalis suis, nadidum, natrum oxalaceticum, pantothenic acid, placenta totalis suis, sanguinaria canadensis, sulphur, piper nigrum, alpha-lipoicum acidum, cartilago suis, rhus tox, silicea, symphytum officinale, thuja occidentalis, apiolum',
#  '.beta.-carotene, ascorbic acid, cholecalciferol, .alpha.-tocopherol, d-, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, cyanocobalamin, calcium carbonate, iron, magnesium, zinc oxide, sodium selenate, cupric oxide, iodine, choline, omega-3 fatty acids',
#  'aconitum napellus, ammonium bromide, citrullus colocynthis fruit pulp, atropine sulfate, gelsemium sempervirens root, magnesium phosphate, dibasic trihydrate, veratrum album root, passiflora incarnata flowering top, matricaria recutita, amanita muscaria fruiting body and cupric sulfate',
#  'fish oil, doconexent, icosapent, thiamine mononitrate, riboflavin, inositol niacinate, pyridoxine hydrochloride, cyanocobalamin, folic acid, ascorbic acid, cholecalciferol, d-alpha-tocopherol, biotin, ferrous fumarate, zinc sulfate monohydrate, cupric sulfate anhydrous, docusate sodium',
#  'doconexent, niacinamide, .alpha.-tocopherol acetate, dl-, cholecalciferol, .beta.-carotene, ascorbic acid, thiamine mononitrate, riboflavin, pyridoxine hydrochloride, cyanocobalamin, iron, zinc oxide, cupric oxide, potassium iodide, magnesium oxide, folic acid, and levomefolate calcium',
#  'doconexent, niacinamide, .alpha.-tocopherol acetate, dl-, cholecalciferol, beta carotene, ascorbic acid, thiamine mononitrate, riboflavin, pyridoxine hydrochloride, cyanocobalamin, iron, zinc oxide, cupric oxide, potassium iodide, magnesium oxide, folic acid, and levomefolate calcium',
#  'arnica montana root, toxicodendron pubescens leaf, solanum dulcamara top, comfrey root, sulfur, sanguinaria canadensis root, sus scrofa cartilage, sus scrofa embryo, sus scrofa umbilical cord, sus scrofa placenta, .alpha.-lipoic acid, coenzyme a, nadide and sodium diethyl oxalacetate',
#  'euphrasia officinalis, ginkgo biloba, petroselinum sativum, vaccinium myrtillus, ascorbic acid, spigelia anthelmia, eye (suis), germanium sesquioxide, lithium metallicum, ubidecarenonum, aurum metallicum, bryonia (alba), hepar sulphuris calcareum, phosphorus, ruta graveolens, sulphur',
#  '.beta.-carotene, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, d-, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, cyanocobalamin, calcium carbonate, iron, magnesium oxide, zinc oxide, cupric oxide, iodine, omega-3 fatty acids',
#  '.beta.-carotene, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, cyanocobalamin, calcium pantothenate, calcium carbonate, ferrous fumarate, zinc oxide, and docusate sodium',
#  '.beta.-carotene, vitamin a acetate, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, levomefolate calcium, cobalamin, iron, magnesium oxide, zinc oxide, and doconexant',
#  'allium sat, aloe, arsenicum alb, berber vulg, calc phos, ceanothus, chelidonium maj, cholesterinum, clematis erecta, condurango, gambogia, hamamelis, kali brom, kali phos, lycopodium, nat carb, passiflora, senna, silicea, solidago, spigelia anth, spongia, veratrum vir',
#  'ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, d-, thiamine hydrochloride, riboflavin, niacin, pyridoxine hydrochloride, levomefolate magnesium, folic acid, cyanocobalamin, iron pentacarbonyl, potassium iodide, magnesium oxide, doconexent, and icosapent',
#  'vitamin a palmitate, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, d-, thiamine hydrochloride, riboflavin, niacinamide, pantothenic acid, pyridoxine hydrochloride, biotin, levomefolate glucosamine, cyanocobalamin, ferrous sulfate, and sodium fluoride',
#  'leucine, phenylalanine, lysine, methionine, isoleucine, valine, histidine, threonine, tryptophan, alanine, glycine, arginine, proline, serine, tyrosine, sodium acetate, dibasic potassium phosphate, magnesium chloride, sodium chloride, calcium chloride, dextrose',
#  'vitamin a acetate, beta carotene, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, cyanocobalamin, calcium carbonate, ferrous fumarate, zinc oxide, cupric oxide',
#  '.beta.-carotene, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, thiamine, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, cyanocobalamin, calcium pantothenate, calcium carbonate, ferrous fumarate, zinc oxide and docusate sodium',
#  'ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, pyridoxine hydrochloride, folic acid, 5-methyltetrahydrofolic acid, cyanocobalamin, biotin, calcium formate, ferrous asparto glycinate, potassium iodide, magnesium oxide, doconexent and icosapent',
#  'echinacea angustifolia, echinacea purpurea, aconitum napellus, arnica montana, calendula officianalis, hamamelis virginiana, belladonna, bellis perennis, chamomillia, millefolium, hypericum perforatum, symphytum officinale, colchicinum, zingiber officinale',
#  'folic acid, .beta.-carotene, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hydrochloride, cyanocobalamin, calcium pantothenate, calcium carbonate, ferrous fumarate, and zinc oxide',
#  'omega-3 fatty acids, icosapent, doconexent, thiamine mononitrate, riboflavin, pyridoxine hydrochloride, cyanocobalamin, folic acid, cholecalciferol, ascorbic acid, .alpha.-tocopherol, d-, cupric sulfate, zinc oxide, ferrous fumarate and magnesium oxide',
#  'vitamin a acetate, ascorbic acid, cholecalciferol, .alpha.-tocopherol, dl-, thiamine hydrochloride, riboflavin, niacinamide, pyridoxine hydrochloride, levomefolic acid, folic acid, cyanocobalamin, magnesium oxide, cupric sulfate, and sodium fluoride',
#  'ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, pyridoxine hydrochloride, folic acid, cyanocobalamin, biotin, calcium carbonate, ferrous asparto glycinate, iron, potassium iodide, magnesium oxide, doconexent and lowbush blueberry',
#  'vitamin a acetate, .beta.-carotene, ascorbic acid, cholecalciferol, .alpha.-tocopherol, thiamine, riboflavin, niacinamide, pyridoxine, levomefolate glucosamine, folic acid, cyanocobalamin, biotin, zinc gluconate, cupric oxide, and sodium fluoride',
#  'isoleucine, leucine, lysine acetate, methionine, phenylalanine, threonine, tryptophan, valine, cysteine hydrochloride, histidine, tyrosine, n-acetyl-tyrosine, alanine, arginine, proline, serine, glycine, aspartic acid, glutamic acid, and taurine',
#  'vitamin a acetate, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, d-, thiamine hydrochloride, riboflavin, niacinamide, pyridoxine hydrochloride, levomefolic acid, cyanocobalamin, magnesium oxide, cupric sulfate, and sodium fluoride',
#  'carduus mar., cynara, solidago, taraxacum, benzoicum ac., berberis vulg., bryonia, cantharis, carduus ben., ceanothus, chelidonium maj., chionanthus. cinchona, dioscorea, dolichos, iris vers., juniperus com., nux vom., ptelea, uricum ac.',
#  'leucine, lysine, isoleucine, valine, histidine, phenylalanine, threonine, methionine, tryptophan, tyrosine, n-acetyl-tyrosine, arginine, proline, alanine, glutamic acide, serine, glycine, aspartic acid, taurine, cysteine hydrochloride',
#  'retinol, ergocalciferol, .alpha.-tocopherol acetate, dl-, phytonadione, ascorbic acid, niacinamide, riboflavin 5-phosphate sodium, thiamine hydrochloride, pyridoxine hydrochloride, dexpanthenol, biotin, folic acid, and cyanocobalamin',
#  'ascorbic acid, vitamin a palmitate, cholecalciferol, thiamine hydrochloride, riboflavin 5-phosphate sodium, pyridoxine hydrochloride, niacinamide, dexpanthenol, alpha-tocopherol acetate, vitamin k1, folic acid, biotin, cyanocobalamin',
#  'ascorbic acid, vitamin a palmitate, cholecalciferol, thiamine hydrochloride, riboflavin-5 phosphate sodium, pyridoxine hydrochloride, niacinamide, dexpanthenol, alpha-tocopherol acetate, vitamin k1, folic acid, biotin, cyanocobalamin',
#  'ascorbic acid, retinol, ergocalciferol, thiamine hydrochloride, riboflavin 5-phosphate sodium, pyridoxine hydrochloride, niacinamide, dexpanthenol, .alpha.-tocopherol acetate, dl-, biotin, folic acid, cyanocobalamin, and phytonadione',
#  'vitamin a, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, thiamine mononitrate, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, cyanocobalamin, calcium carbonate, iron, zinc oxide, and cupric oxide',
#  'ascorbic acid, cholecalciferol, dl-.alpha.-tocopherol acetate, thiamine hydrochloride, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, cyanocobalamin, calcium carbonate, ferrous fumarate, zinc oxide, cupric sulfate',
#  'aconitum napellus, anamirta cocculus seed, citrullus colocynthis fruit, gelsemium sempervirens root, lachesis muta venom, daphne mezereum bark, strychnos nux-vomica seed, lead acetate anhydrous, and toxicodendron pubescens shoot',
#  'iron, sodium ascorbate, thiamine mononitrate, riboflavin, pyridoxine hydrochloride, folic acid, cyanocobalamin, niacinamide, calcium pantothenate, zinc sulfate, magnesium sulfate, manganese sulfate, and cupric sulfate anhydrous',
#  'cochlearia armoracia, spleen (bovine), thymus gland (bovine), influenzinum (2019-2020), mycoplasma pneumoniae, cytomegalovirus nosode, human papilloma nosode, coxsackie b1 nosode, coxsackie b4 nosode, pneumococcinum, carcinosin',
#  'imuflex wb-rp blood bag system with integral whole blood leukocyte reduction filter (removing platelets) with diversion blood sampling arm anticoagulant citrate phosphate dextrose (cpd) and optisol (as-5) red cell preservative',
#  'imuflex wb-sp blood bag system with integral whole blood leukocyte reduction filter (saving platelets) with diversion blood sampling arm anticoagulant citrate phosphate dextrose (cpd) and optisol (as-5) red cell preservative',
#  'arsenic trioxide, clematis recta flowering top, lachesis muta venom, mercuric cyanide, phytolacca americana root, toxicodendron pubescens shoot, scrophularia nodosa leaf with stem, sulfur, and thuja occidentalis leafy twig',
#  'dextrose, soybean oil, electrolytes, lysine, phenylalanine, leucine, valine, threonine, methionine, isoleucine, tryptophan, alanine, arginine, glycine, proline, histidine, glutamic acid, serine, aspartic acid and tyrosine',
#  'ascorbic acid, calcium citrate, iron, vitamin d, dl- alpha- tocopherol acetate, thiamine, riboflavin, niacinamide, pyridoxine hydrochloride, folic acid, iodine, zinc, copper, docusate sodium, doconexent and icosapent',
#  'ribes nigrum, viburnum opulus, quebracho, blatta orientalis, pothos foetidus, cinnamic acid, gallicum acidum, indolum, quercetin, rutin, arsenicum iodatum, naphthalinum, coumarinum, oxygenium, house dust mite, malvin',
#  'baptisia tinctoria, echinacea (angustifolia), hydrastis canadensis, phytolacca decandra, arsenicum album, bryonia (alba), eupatorium perfoliatum, ferrum phosphoricum, gelsemium sempervirens, ipecacuanha, rhus tox',
#  'aceticum acidum, anacardium orientale, baryta iodata, calcarea carbonica, capsicum annum, fucus vesiculosus, graphites, natrum sulphuricum, phytolacca decandra, stannum metallicum, thyrdoidinum, zinum metallicum',
#  'baryta iodata, cactus grandiflorus, carbo vegetabilis, crataegus oxyacantha, curare, kali carbonicum, kalmia latifolia, melilotus officinale, naja tripudians, secale cornutum, solanum nigrum, spigelia anthelmia',
#  'vitamin a, ascorbic acid, vitamin d, .alpha.-tocopherol, thiamine mononitrate, riboflavin, niacin, pyridoxine hydrochloride, folic acid, cyanocobalamin, calcium, iron, magnesium, zinc, copper, and doconexent',
#  'ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, folic acid, pyridoxine hydrochloride, cyanocobalamin, biotin, calcium carbonate, ferrous fumarate, magnesium oxide, lactic acid and doconexent',
#  'alternaria tenuis, aspergillus niger, candida albicans, candida parapsilosis, mucor racemosus, pullularia pullulans, rhizopus nigricans, torula cerevisiae, arsenicum album, phosphorus, pulsatilla, sepia',
#  'isoleucine, leucine, lysine acetate, methionine, phenylalanine, threonine, tryptophan, valine, alanine, arginine, aspartic acid, glutamic acid, glycine, histidine, proline, serine, taurine, and tyrosine',
#  'apis mellifica, aranea diadema, berberis vulgaris, equisetum hyemale, galium aparine, juglans regia, manganum phosphoricum, nicotinamidum, nitricum acidum, sarsaparilla, thuja occidentalis, urtica urens',
#  'ascorbic acid, biotin, cholecalciferol, cyanocobalamin, folic acid, ferrous asparto glycinate, potassium iodide, pyridoxine hydrochloride, .alpha.-tocopherol acetate, dl-, docusate sodium and blueberry',
#  'isoleucine, leucine, lysine acetate, methionine, phenylalanine, threonine, tryptophan, valine, alanine, arginine, aspartic acid, glutamic acid, histidine, proline, serine, n-acetyltyrosine, and glycine',
#  'echinacea (angustifolia), allium cepa, bryonia (alba), gelsemium sempervirens, sanguinaria canadensis, eupatorium perfoliatum, kali bichromicum, phosphorus, aconitum napellus, influenzinum 2019-2020',
#  'vitamin a, ascorbic acid, cholecalciferol, alpha-tocopherol acetate, thiamine hydrochloride, riboflavin 5-phosphate sodium, niacinamide, pyridoxine hydrochloride, ferrous sulfate and sodium fluoride',
#  'vitamin a, ascorbic acid, cholecalciferol, alpha-tocopherol acetate, thiamine hydrochloride, riboflavin 5-phosphate sodium, cyanocobalamin, niacinamide, pyridoxine hydrochloride and sodium fluoride',
#  'vitamin a, ascorbic acid, vitamin d, .alpha.-tocopherol, thiamine mononitrate, riboflavin, niacin, pyridoxine hydrochloride, folic acid, cyanocobalamin, calcium, iron, magnesium, zinc, and copper',
#  'amiloride - apis mellifera - berberis vulgaris fruit - hieracium pilosella flowering top - hydrochlorothiazide - solidago virgaurea flowering top - spironolactone - sus scrofa pituitary gland -',
#  'lysine acetate, leucine, phenylalanine, valine, isoleucine, methionine, threonine, tryptophan, alanine, arginine, glycine, histidine, proline, glutamic acid, serine, aspartic acid, and tyrosine',
#  'benzoicum acidum, pulsatilla (vulgaris), rhododendron chrysanthum, spiraea ulmaria, aconitum napellus, dulcamara, ledum palustre, asclepias tuberosa, lithium benzoicum, euphorbium officinarum',
#  'isoleucine, leucine, lysine, methionine, phenylalanine, threonine, tryptophan, valine, alanine, arginine, histidine, proline, serine, glycine, cysteine, phosphoric acid, and sodium bisulfite',
#  'calc carb, chenopodium anth, cina, croton, filix mas, gambocia, granatum, lycopodium, merc corros, nat phos, santoninum, senna, spigelia anth, stannum met, tanacetum, teuricum mar, zingiber',
#  'adamas, agaricus musc, agnus, aletris, angelica sin, arg nit, arnica, avena, baryta, graphites, kali brom, kreosotum, lycopodium, ocimum sanc, phosphoricum ac, selenium, sepia, thuja occ.',
#  '.beta.-carotene, ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, d-, thiamine mononitrate, riboflavin, pyridoxine hydrochloride, folic acid, cyanocobalamin, iron, niacinamide',
#  'ascorbic acid, cholecalciferol, .alpha.-tocopherol, dl-, folic acid, pyridoxine hydrochloride, cyanocobalamin, calcium formate, ferrous asparto glycinate, magnesium oxide and doconexent',
#  'valine, lysine, histidine, isoleucine, leucine, phenylalanine, threonine, methionine, tryptophan, alanine, glycine, arginine, proline, glutamic acid, serine, aspartic acid and tyrosine',
#  'pseudognaphalium obtusifolium, causticum, colchicum autumnale bulb, citrullus colocynthis fruit pulp, iron, lithium benzoate, toxicodendron pubescens leaf and filipendula ulmaria root',
#  'apis mellifera, silver nitrate, atropa belladonna, lytta vesicatoria, causticum, equisetum hyemale, petroselinum crispum, pulsatilla vulgaris, smilax regelii root, and turpentine oil',
#  'lysine, leucine, phenylalanine, valine, histidine, isoleucine, methionine, threonine, tryptophan, alanine, arginine, glycine, proline, glutamic acid, serine, aspartic acid, tyrosine',
#  'ascorbic acid, cholecalciferol, .alpha.-tocopherol, pyridoxine, folic acid, cyanocobalamin, calcium corbonate, ferrous fumarate, potassium iodide, magnesium, doconexent, icosapent',
#  'black cohosh, anamirta cocculus seed, cypripedium parvifolum root, strychnos ignatii seed, passiflora incarnata flowering top, platinum, valerian, and zinc valerate dihydrate',
#  'isoleucine, leucine, lysine, methionine, phenylalanine, threonine, tryptophan, valine, alanine, arginine, histidine, proline, serine, glycine, cysteine, and sodium bisulfite',
#  '.alpha.-tocopherol acetate, dl-, ascorbic acid, cyanocobalamin, folic acid, niacin, pyridoxine, riboflavin, sodium fluoride, thiamine mononitrate, vitamin a and vitamin d',
#  'aconitum napellus, aesculus hippocastanum, colocynthis, gnaphalium polycephalum, hypericum perforatum, magnesia phosphorica, plumbum metallicum, rhus tox, arnica montana',
#  'leucine, phenylalanine, lysine hydrochloride, methionine, isoleucine, valine, histidine, threonine, tryptophan, alanine, glycine, arginine, proline, tyrosine, serine',
#  'chenopodium anthelminticum, cina, cucurbita, pepo, cuprum oxydatum nigrum, filix mas, granatum, kousso, ratanhia, santoninum, sabadilla, spigelia, teucrium marum.',
#  'leucine, phenylalanine, lysine, methionine, isoleucine, valine, histidine, threonine, tryptophan, alanine, glycine, arginine, proline, serine, tyrosine, dextrose',
#  'crataegus laevigata, cactus grandiflorus, convallaria majalis, camphor, kalmia latifolia, spigelia anthelmia, lachesis mutus, arnica montana, tabacum, glonoinum',
#  'alfalfa, aralia quin (ginseng), avena, calc phos, cinchona, ferrum phos, hydrastis, kali iod, kali mur, kali phos, mag phos, nat phos, nux vom, phosphoricum ac.',
#  'ascorbic acid, cholecalciferol, alpha-tocopherol, thiamine, riboflavin, niacinamide, pyridoxine, folic acid, cobalamin, biotin, pantothenic acid, zinc, selenium',
#  'arnica montana, calcarea phosphorica, causticum, china officinalis, colchicum autumnale, dulcamara, ledum palustre, rhus toxicodendron, symphytum officinale',
#  'calcium citrate, iron pentacarbonyl, cholecalciferol, .alpha.-tocopherol acetate, dl-, pyridoxine hydrochloride, folic acid, docusate sodium and doconexent',
#  'dextrose monohydrate, sodium lactate, potassium chloride, magnesium chloride, potassium phosphate, monobasic, and sodium phosphate, monobasic, monohydrate',
#  'ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, pyridoxine, folic acid, cyanocobalamin, calcium, ferrous fumarate, magnesium, doconexent',
#  'ascorbic acid, tocopheryl acid succinate, thiamine, riboflavin, niacinamide, pyridoxine, folic acid, cobalamin, biotin, pantothenic acid, zinc, selenium',
#  'sodium chloride, sodium gluconate, sodium acetate, potassium chloride, magnesium chloride, sodium phosphate, dibasic, and potassium phosphate, monobasic',
#  'calcium citrate, iron pentacarbonyl, ferrous fumarate, cholecalciferol, .alpha.-tocopherol, dl-, pyridoxine hydrochloride, folic acid, and doconexent',
#  'calcium citrate, iron pentacarbonyl, cholecalciferol, .alpha.-tocopherol, dl-, pyridoxine hydrochloride, folic acid, docusate sodium, and doconexent',
#  'apil mel, baptisia, baryta carb, hamamelis, kali brom, kali phos, lachesis, lilium, petroleum, phosphoricum ac, spigelia anth, sulphur, veratrum vir',
#  'teruflex blood bag system with diversion blood sampling arm anticoagulant citrate phosphate dextrose (cpd) and optisol (as-5) red cell preservative',
#  'dextrose monohydrate, trisodium citrate dihydrate, sodium chloride, sodium phosphate, monobasic, monohydrate, citric acid monohydrate, and adenine',
#  'arnica montana, echinacea angustifolia, hypericum perforatum, phosphorus, rancid beef, silicon dioxide, delphinium staphisagria seed, comfrey root',
#  'vitamin c, calcium, iron, vitamin d3, vitamin e, thiamin, riboflavin, niacinamide, vitamin b6, folic acid, iodine, zinc, copper, docusate sodium',
#  'arnica montana, borax, calendula officinalis, hypericum perforatum, myrrha, plantago major, ratanhia, salvia officinalis, symphytum officinale.',
#  'betamethasone sodium phosphate, betamethasone acetate, lidocaine hydrochloride, bupivacaine hydrochloride, povidine iodine, isopropyl alcohol',
#  'sodium chloride, sodium gluconate, sodium acetate, potassium chloride, magnesium chloride, sodium phosphate, dibasic, and potassium phosphate',
#  'citric acid monohydrate, sodium phosphate, monobasic, monohydrate, sodium chloride, adenine, anhydrous dextrose, trisodium citrate dihydrate',
#  'arnica montana, calendula officinalis flowering top, echinacea angustifolia, st. johns wort, silver, sulfur, allylthiourea and urtica urens',
#  'dihydroergocornine mesylate, dihydroergocristine mesylate, dihydro-.alpha.-ergocryptine mesylate, and dihydro-.beta.-ergocryptine mesylate',
#  'vitamin a, vitamin c, vitamin d, vitamin e, thiamine, riboflavin, niacin, vitamin b6, folic acid, vitamin b12, calcium, iron, zinc, copper',
#  'teruflex blood bag system with blood sampling arm anticoagulant citrate phosphate dextrose (cpd) and optisol (as-5) red cell preservative',
#  'imuflex wb-sp blood bag system with integral whole blood leukocyte reduction filter (saving platelets) with diversion blood sampling arm',
#  'aesculus hippocastanum, arnica montana, calendula officinalis, echinacea purpurea, hamamelis virginiana, paeonia officinalis, ratanhia.',
#  'calcium carbonate, cholecalciferol, magnesium oxide, boron, folic acid, pyridoxine hydrochloride, cyanocobalamin, biotin and bilberry',
#  'dextroamphetamine saccharate, amphetamine aspartate monohydrate, dextroamphetamine sulfate, and amphetamine sulfate extended-release',
#  'dextrose monohydrate, sodium citrate, sodium chloride, sodium phosphate, monobasic, monohydrate, citric acid monohydrate and adenine',
#  'calcium chloride, magnesium chloride, sodium chloride, sodium bicarbonate, potassium chloride and sodium phosphate dibasic dihydrate',
#  'methylprednisolone acetate, lidocaine hydrochloride, bupivacaine hydrochloride, povidine iodine, sodium chloride, isopropyl alcohol',
#  'calcium chloride, magnesium chloride, dextrose monohydrate, lactic acid, sodium chloride, sodium bicarbonate and potassium chloride',
#  'vitamin c, vitamin d, vitamin e, thiamine, riboflavin, niacin, vitamin b6, folate, vitamin b12, biotin, pantothenic acid, chromium',
#  'dextroamphetamine saccharate, amphetamine aspartate monohydrate, dextroamphetamine sulfate, amphetamine sulfate extended-release',
#  'sodium cation, sodium bicarbonate, anhydrous dextrose, magnesium sulfate, potassium chloride, calcium chloride, sodium phosphate',
#  'sodium lactate, potassium chloride, magnesium chloride, monobasic potassium phosphate, sodium chloride and dextrose monohydrate',
#  'ascorbic acid, cholecalciferol, .alpha.-tocopherol acetate, dl-, pyridoxine, folic acid, calcium, ferrous fumarate, doconexent',
#  'sodium chloride, potassium chloride, calcium chloride, magnesium chloride, sodium acetate and trisodium citrate dihydrate',
#  'vitamin a, vitamin c, vitamin d-3, vitamin e, vitamin b-1, vitamin b-2, niacin, vitamin b-6, calcium, iron, zinc, copper',
#  'mepivacaine hydrochloride, lidocaine hydrochloride, epinephrine bitartrate, iodine, potassium iodide, ferric subsulfate',
#  'allium sat, anacardium, apis mel, gambogia, merc solub, nat carb, nitricum ac, nux vom, phosphorus, pulsatilla, sulphur',
#  'dextroamphetamine saccharate, amphetamine aspartate, dextroamphetamine sulfate, amphetamine sulfate tablets, 10 mg,cll',
#  'dextroamphetamine saccharate, amphetamine aspartate, dextroamphetamine sulfate, amphetamine sulfate tablets, 30 mg,cll',
#  'dextroamphetamine saccharate, amphetamine aspartate, dextroamphetamine sulfate, amphetamine sulfate tablets, 15 mg,cll',
#  'dextroamphetamine saccharate, amphetamine aspartate, dextroamphetamine sulfate, amphetamine sulfate tablets, 20 mg,cll',
#  'polyethylene glycol 3350, sodium chloride, sodium bicarbonate, potassium chloride and bisacodyl delayed-release tablet',
#  'ferrous asparto glycinate, iron, ascorbic acid, folic acid, cyanocobalamin, zinc, succinic acid, and intrinsic factor',
#  'dextroamphetamine saccharate, amphetamine aspartate, dextroamphetamine sulfate, amphetamine sulfate tablets, 5 mg,cll',
#  'fish oil, dha, epa, vitamins b-1, b-2, b-3, b-6, b-12, c, d3, e, biotin, iron, zinc, copper, iodine, docusate sodium',
#  'dextroamphetamine sulfate, dextroamphetamine saccharate, amphetamine aspartate monohydrate, and amphetamine sulfate',
#  'cimex lectularius, formica rufa, pulex irritans, vespa crabro, apis mellifica, hypericum perforatum, ledum palustre',
#  'ascorbic acid, thiamine, riboflavin, niacinamide, pyridoxine, folic acid, cobalamin, biotin, pantothenic acid, zinc',
#  'dextroamphetamine saccharate, amphetamine aspartate monohydrate, dextroamphetamine sulfate, and amphetamine sulfate',
#  'dextroamphetamine saccharate, amphetamine aspartate monohydrate, dextroamphetamine sulfate and amphetamine sulfate',
#  'methylprednisolone acetate, lidocaine hydrochloride, bupivacaine hydrochloride, povidine iodine, isopropyl alcohol',
#  'magnesium chloride, sodium chloride, sodium bicarbonate, potassium chloride and sodium phosphate dibasic dihydrate',
#  'citric acid monohydrate, trisodium citrate dihydrate, sodium phosphate, monobasic, monohydrate, anhydrous dextrose',
#  'ferrous asparto glycinate, ferrous fumarate, ascorbic acid, folic acid, cyanocobalamin, zinc, and intrinsic factor',
#  'dextroamphetamine saccharate, amphetamine aspartate monohydrate, dextroamphetamine sulfate, amphetamine sulfate er',
#  'ascorbic acid, thiamine, riboflavin, niacinamide, pyridoxine, folic acid, cyanocobalamin, biotin, pantothenic acid',
#  'sodium phosphate, dibasic, anhydrous, potassium phosphate, monobasic, and sodium phosphate, monobasic, monohydrate',
#  'polyethylene glycol 3350, sodium sulfate, sodium chloride, potassium chloride, sodium ascorbate, and ascorbic acid',
#  'hyoscyamine sulfate, methenamine, methylene blue, phenyl salicylate, and sodium phosphate, monobasic, monohydrate',
#  'methenamine, sodium phosphate, monobasic, monohydrate, phenyl salicylate, methylene blue, and hyoscyamine sulfate',
#  'magnesium chloride, dextrose monohydrate, lactic acid, sodium chloride, sodium bicarbonate and potassium chloride',
#  'calc fluor, causticum, graphites, hydrofluoricum ac, lachesis, plumb met, rhus tox, sepia, silicea, thiosinaminum',
#  'dextrose, sodium chloride, sodium acetate anhydrous, sodium gluconate, potassium chloride, and magnesium chloride',
#  'dextroamphetamine saccharate, amphetamine aspartate monohydrate, dextroamphetamine sulfate, amphetamine sulfate',
#  'calcium chloride, magnesium chloride, dextrose monohydrate, lactic acid, sodium chloride and sodium bicarbonate',
#  'dextroamphetamine saccharate, amphetamine aspartate, dextroamphetamine sulfate, amphetamine sulfate tablets,cii',
#  'methenamine, sodium phosphate, monobasic, anhydrous, phenyl salicylate, methylene blue and hyoscyamine sulfate',
#  'polyethylene glycol 3350, sodium sulfate, sodium chloride, potassium chloride, ascorbic acid, sodium ascorbate',
#  'adrenal gland, adrenocorticotrophin, cerebrum, liver gland, pituitarum posterium gland, placenta, thyroidinum.',
#  'ascorbic acid, thiamine, riboflavin, niacinamide, pyridoxine, folic acid, cobalamin, biotin, pantothenic acid',
#  'sodium chloride, potassium chloride, calcium chloride, magnesium chloride, sodium acetate, and sodium citrate',
#  'aquilegia, avena, chamomilla, coffea cruda, cypripedium, humulus, kali phos, passiflora, valeriana, zinc met',
#  'dextroamphetamine saccharate and amphetamine aspartate and dextroamphetamine sulfate and amphetamine sulfate',
#  'lidocaine hydrochloride, bupivacaine hydrochloride, betamethasone sodium phosphate and betamethasone acetate',
#  'semecarpus anacardium juice, anamirta cocculus seed, conium maculatum flowering top, kerosene, and selenium',
#  'polyethylene glycol 3350, sodium sulfate anhydrous, sodium bicarbonate, sodium chloride, potassium chloride',
#  'thiamine hydrochloride, riboflavin 5-phosphate sodium, pyridoxine hydrochloride, dexpanthenol, niacinamide',
#  'sodium pyruvate, inosine, adenine, sodium phosphate, dibasic, and sodium phosphate, monobasic, monohydrate',
#  'teruflex blood bag system anticoagulant citrate phosphate dextrose (cpd) and optisol red cell preservative',
#  'calcium chloride, magnesium chloride, potassium chloride, sodium acetate, sodium chloride, sodium citrate',
#  'calcarea carbonica, kali carbonicum, naja tripudians, oophorinum, lachesis mutus, pulsatilla, orchitinum',
#  'polyethylene glycol 3350, sodium chloride, sodium bicarbonate and potassium chloride with orange flavor',
#  'lidocaine hydrochloride, epinephrine bitartrate, ferric subsulfate aqueous, iodine and potassium iodide',
#  'dextroamphetamine saccharate, amphetamine aspartate, dextroamphetamine sulfate, and amphetamine sulfate',
#  'sodium chloride, sodium acetate anhydrous, sodium gluconate, potassium chloride, and magnesium chloride',
#  'sodium chloride, calcium chloride, potassium chloride, magnesium chloride, and sodium acetate anhydrous',
#  'dextroamphetamine sulfate, dextroamphetamine saccharate, amphetamine sulfate and amphetamine aspartate',
#  'polyethylene glycol 3350, sodium chloride, sodium bicarbonate and potassium chloride with lemon flavor',
#  'dextroamphetamine saccharate, amphetamine aspartate, dextroamphetamine sulfate and amphetamine sulfate',
#  'dextroamphetamine saccharate, amphetamine aspartate, dextroamphetamine sulfate and amphetamine suflate',
#  'polyethylene glycol 3350, sodium chloride, potassium chloride, sodium bicarbonate, and sodium sulfate',
#  'betamethasone sodium phosphate and betamethasone acetate, bupivacaine hydrochloride, povidine iodine',
#  'isoleucine, leucine, lysine acetate, methionine, phenylalanine, threonine, tryptophan, valine, alani',
#  'dextrose, sodium acetate, potassium chloride, magnesium chloride, and potassium phosphate, dibasic',
#  'apis mellifica, cantharis, ignatia amara, phosphorus, belladonna, hypophysis, mag carb, pulsatilla',
#  'peg-3350, sodium sulfate, sodium chloride, potassium chloride, sodium ascorbate and ascorbic acid',
#  'sodium chloride, potassium chloride, magnesium sulfate, sodium phosphate, and potassium phosphate',
#  'polyethylene glycol 3350, sodium chloride, sodium bicarbonate and potassium chloride - unflavored',
#  'bismuth subsalicylate chewable tablets/metronidazole tablets/tetracycline hydrochloride capsules',
#  'methenamine, sodium phosphate monobasic, phenyl salicylate, methylene blue, hyoscyamine sulfate',
#  'sodium chloride, sodium lactate, potassium chloride, calcium chloride, and dextrose monohydrate',
#  'potassium chloride, sodium chloride, calcium chloride, sodium lactate, and dextrose monohydrate',
#  'ascorbic acid, calcium citrate, iron, cholecalciferol, pyridoxine hydrochloride, and folic acid',
#  'sodium chloride, sodium lactate, potassium chloride, calcium chloride and dextrose monohydrate',
#  'bufo rana, glandula suprarenalis, pulsatilla, cuprum metallicum, phosphorus, zincum metallicum',
#  'sodium chloride, sodium gluconate, sodium acetate, potassium chloride, and magnesium chloride',
#  'calcarea phosphorica, cuprum metallicum, oophorinum, veratrum album, orchitinum, vipera berus',
#  'amphotericin b, dimyristoylphosphatidylcholine, dl- and dimyristoylphosphatidylglycerol, dl-',
#  'triamcinolone acetonide, lidocaine hydrochloride, bupivacaine hydrochloride, povidine iodine',
#  'vitamin c, vitamin d, vitamin e, vitamin b6, folate, vitamin b12, iron, zinc, magnesium, dha',
#  'sodium chloride, sodium gluconate, sodium acetate, potassium chloride and magnesium chloride',
#  'dextrose monohydrate, sodium chloride, sodium lactate, calcium chloride, magnesium chloride',
#  'dextrose monohydrate, sodium chloride, sodium lactate, potassium chloride, calcium chloride',
#  'ketorolac tromethamine, lidocaine hydrochloride, bupivacaine hydrochloride, povidine iodine',
#  'aur met, cerebrum, lachesis mutus, valeriana, calc sulf, hypericum perforatum, millefolium',
#  'brompheniramine maleate, pseudoephedrine hydrochloride, and dextromethorphan hydrobromide',
#  'brompheniramine maleate, pseudoephedrine hydrochloride and dextromethorphan hydrobromide',
#  'viatmin c, thiamine, vitamin b6, folate,vitamin b12, vitamin b3, d-ribose, coenzyme q-10',
#  'methylprednisolone acetate, lidocaine hydrochloride, povidine iodine, isopropyl alcohol',
#  'anticoagulant citrate phosphate dextrose (cpd) solution and adsol preservation solution',
#  'brompheniramine maleate, pseudoephedrine hydrochloride and dextromethorphanhydrobromide',
#  'proteus inconstans,proteus mirabilis,proteus morgani,proteus rettgeri,proteus vulgaris',
#  'dibasic sodium phosphate, monobasic potassium phosphate and monobasic sodium phosphate',
#  'doxylamine succinate and pyridoxine hydrochloride, delayed release tablets 10 mg/10 mg',
#  'nickel sulfate, potassium bromide, sodium bromide, zinc sulfate anhydrous, and sulfur',
#  'brompheniramine maleate, pseudoephedrine hydrochloride, dextromethorphan hydrobromide',
#  'methenamine, benzoic acid, phenyl salicylate, methylene blue, and hyoscyamine sulfate',
#  'polyethylene glyocol 3350, sodium chloride, sodium bicarbonate and potassium chloride',
#  'polyethylene glycol 3350, sodium chloride, sodium bicarbonate and potassium chloride',
#  'aconitum nap, arg nit, chininum pur, echinacea purp, plum met, sepia, sulphuricum ac',
#  'polyethylene glycol-3350, sodium chloride, potassium chloride and sodium bicarbonate',
#  'dextrose, sodium chloride, sodium lactate, potassium chloride, and calcium chloride',
#  'dexamethasone sodium phosphate, lidocaine hydrochloride, maricaine, povidine iodine',
#  'potassium bicarbonate and potassium chloride effervescent tablets for oral solution',
#  'teruflex blood bag system anticoagulant citrate phosphate dextrose adenine (cpda-1)',
#  'norethindrone acetate and ethinyl estradiol, ethinyl estradiol and ferrous fumarate',
#  'thiamine hydrochloride, riboflavin 5 phosphate sodium, dexpanthenol and niacinamide',
#  'calc carb, moschus, stramonium, thymus gland, hyoscyamus niger, plumb met, sulphur',
#  'sodium chloride, sodium lactate, calcium chloride, magnesium chloride and dextrose',
#  'phenobarbital, hyoscyamine sulfate, atropine sulfate, and scopolamine hydrobromide',
#  'liquid b homeopathic, hordeum vulgare, hepar suis, heart (suis), torula cerevisiae',
#  'milk thistle, chelidonium majus root, quassia amara wood, and taraxacum officinale',
#  'polyethylene glycol 3350, sodium chloride, sodium bicarbonate, potassium chloride',
#  'standardized mite mix dermatophagoides farinae and dermatophagoides pteronyssinus',
#  'colistin sulfate, neomycin sulfate, thonzonium bromide and hydrocortisone acetate',
#  'betamethasone sodium phosphate, betamethasone acetate, lidocaine, povidine iodine',
#  'methenamine, sodium phosphate, monobasic, methylene blue, and hyoscyamine sulfate',
#  'adsol red cell preservation solution system in plastic container (pl 146 plastic)',
#  'phenobarbital, hyoscyamine sulfate, atropine sulfate and scopolamine hydrobromide',
#  'drospirenone, ethinyl estradiol and levomefolate calcium and levomefolate calcium',
#  'sodium phosphate, monobasic, monohydrate and sodium phosphate, dibasic, anhydrous',
#  'zo skin health pigment control plus brightening creme hydroquinone plus vitamin c',
#  'icodextrin, sodium chloride, sodium lactate, calcium chloride, magnesium chloride',
#  'anticoagulant citrate phosphate dextrose (cpd) blood-pack units in pl 146 plastic',
#  'ammon carb, chininum ars, graphites, calcarea carbonica, eschscholtzia, pancreas',
#  'staphylococcus epidermidis, staphylococcus haemolyticus, staphylococcus simulans',
#  'norethindrone acetate and ethinyl estradiol tablets and ferrous fumarate tablets',
#  'sodium lactate, potassium chloride, calcium chloride, sodium chloride, dextrose',
#  'kit for the preparation of technetium tc 99m exametazime for leukocyte labeling',
#  'dextrose monohydrate, sodium chloride, potassium acetate, and magnesium acetate',
#  'citric acid monohydrate, dextrose monohydrate, and trisodium citrate dihydrate',
#  'adrenalinum, cholesterinum, folliculinum, hypothalamus, oophorinum, pulsatilla',
#  'phenobarbital, hyoscyamine sulfate, atropine sulfate, scopolamine hydrobromide',
#  'aconitum napellus, ambra grisea, eschscholtzia, thymus gland, secale, zinc met',
#  'potassium chloride, sodium chloride, calcium chloride, and magnesium chloride',
#  'olmesartan medoxomil, amlodipine and hydrochlorothiazide tablet 40/10/12.5 mg',
#  'anticoagulant citrate phosphate dextrose (cpd) and as-5 red cell preservative',
#  'promethazine hydrochloride, phenylephrine hydrochloride and codeine phosphate',
#  'neomycin and polymyxin b sulfates, bacitracin zinc and hydrocortisone acetate',
#  'adrenalinum, cimicifuga, ignatia, lecithin, nicotinamidum, oophorinum, sepia.',
#  'sodium phosphate, monobasic, monohydrate, sodium phosphate, dibasic anhydrous',
#  'anticoagulant citrate phosphate dextrose solution with additive solution as-1',
#  'olmesartan medoxomil, amlodipine and hydrochlorothiazide tablet 20/5/12.5 mg',
#  'olmesartan medoxomil, amlodipine and hydrochlorothiazide tablet 40/5/12.5 mg',
#  'calcium chloride, magnesium chloride, potassium chloride and sodium chloride',
#  'neomycin sulfate and polymyxin b sulfate, bacitracin zinc and hydrocortisone',
#  'drospirenone/ethinyl estradiol/levomefolate calcium and levomefolate calcium',
#  'anhydrous citric acid, dextrose monohydrate, and trisodium citrate dihydrate',
#  'balanced salt solution enriched with bicarbonate, dextrose, and glutathione',
#  'haemonetics anticoagulant citrate phosphate double dextrose solution (cp2d)',
#  'olmesartan medoxomil, amlodipine and hydrochlorothiazide tablet 40/10/25 mg',
#  'apis mellifica, oophorinum, platinum met, orchitinum, petroleum, stramonium',
#  'bryonia, gelsemium sempervirens, sambucus nigra, sulphur, zincum gluconicum',
#  'emtricitabine, rilpivirine hydrochloride, and tenofovir disoproxil fumarate',
#  'olmesartan medoxomil, amlodipine and hydrochlorothiazide tablet 40/5/25 mg',
#  'dexamethasone sodium phosphate, bupivacaine hydrochloride, povidine iodine',
#  'elvitegravir, cobicistat, emtricitabine, and tenofovir disoproxil fumarate',
#  'promethazine hydrochloride and dextromethorphan hydrobromide oral solution',
#  'ammonia, lidocaine hydrochloride, triamcinolone acetonide, povidone-iodine',
#  'dexamethasone sodium phosphate, ropivacaine hydrochloride, povidine iodine',
#  'neomycin sulfate, polymyxin b sulfate, bacitracin zinc and hydrocortisone',
#  'sodium chloride, sodium lactate, potassium chloride, and calcium chloride',
#  'cholecalciferol, pyridoxine hydrochloride, cyanocobalamin, and folic acid',
#  'sodium chloride, soldium lactate, potassium chloride and calcium chloride',
#  'anticoagulant citrate phosphate dextrose (cpd) and adsol preservation kit',
#  'agnus castus, hepar sulph calc, pancreas, arum triph, lachesis, petroleum',
#  'cholecalciferol, magnesium, boron, folic acid, pyridoxine, cyanocobalamin',
#  'potassium phosphate, monobasic and sodium phosphate, monobasic, anhydrous',
#  'apis mellifica, conium, oophorinum, bovista, hepar sulph calc, orchitinum',
#  'sodium chloride, sodium lactate, potassium chloride and calcium chloride',
#  'dexamethasone sodium phosphate, lidocaine hydrochloride, povidine iodine',
#  'iron, folic acid, cyanocobalamin, ascorbic acid, docusate sodium and dha',
#  'sodium chloride, potassium chloride, sodium lactate and calcium chloride',
# ...
#  'lidocaine hci and epinephrine with epinephrine',
#  'aliskiren hemifumarate and hydrochlorothiazide',
#  'clindamycin phoaphate topical solution usp, 1%',
#  'anticoagulant citrate phosphate dextrose (cpd)',
#  'theraworx relief muscle cramp and spasm relief',
#  'gibson healthcare buffered hemostatic solution',
#  'fluticasone furoate and vilanterol trifenatate',
#  'haemonetics additive solution formula 3 (as-3)',
#  'essential fatty acids, multivitamins, minerals',
#  'ciprofloxacin hydrochloride and hydrocortisone',
#  'dx2 oragenomic medicated dna collection screen',
#  'pramoxine hydrochloride hydrocortisone acetate',
#  'phenobarbital with belladonna alkaloids - mint',
#  'pilocarpine hydrochloride ophthalmic solution',
#  'marcaine, lidocaine, kenalog, povidone iodine',
#  'ibuprofen,methyl salicylate/menthol/capsaicin',
#  'celecoxib,methyl salicylate/menthol/capsaicin',
#  'vitamin c, vitamin b12, vitamin k mk7, folate',
#  'olopatadine hydrochloride ophthalmic solution',
#  'ferrous fumarate, polysaccharide iron complex',
#  'depo-medrol, lidocaine hci, isopropyl alcohol',
#  'neomycin, polymyxin b sulfates, dexamethasone',
#  'sulfacetamide sodium and prednisolone acetate',
#  'amlodipine besylate and olmesartran medoxomil',
#  'meloxicam,methyl salicylate/menthol/capsaicin',
#  'physician ez use joint tunnel and trigger kit',
#  'bivalirudin in 0.9% sodium chloride injection',
#  'potassium citrate and citric acid monohydrate',
#  'compare2 black elderberry cold and flu relief',
#  'north american coral snake antivenin (equine)',
#  'fluocinolone acetonide oil, 0.01% (ear drops)',
#  'dorzolamide hydrochloride and timolol maleate',
#  'candesartan cilexetil and hydrochlorothiazide',
#  'dash chlorhexidine gluconate 0.12% oral rinse',
#  'dorzolamide hydrochloride ophthalmic solution',
#  'potassium bromide, nickel sulfate, and sulfur',
#  'amlodipine, valsartan and hydrochlorothiazide',
#  'etodolac,methyl salicylate/menthol/capsaicin',
#  'hydroxyamphetamine hydrobromide, tropicamide',
#  'lamivudine and tenofovir disoproxil fumarate',
#  'sterile cord blood collection unit (msc127d)',
#  'perphenazine and amitriptyline hydrochloride',
#  'leuprolide acetate and norethindrone acetate',
#  'sterile cord blood collection unit (msc123d)',
#  'atoltivimab, maftivimab, and odesivimab-ebgn',
#  'polymyxin b sulfate and trimethoprim sulfate',
#  'amlodipine valsartan and hydrochlorothiazide',
#  'amlodipine besylate and olmesartan medoxomil',
#  'perindopril arginine and amlodipine besylate',
#  'budesonide and formoterol fumarate dihydrate',
#  'amlodipine besylate and atorvastatin calcium',
#  'trimethoprim sulfate and polymyxin b sulfate',
#  '071023 econazole nitrate 1% / niacinamide 4%',
#  'sterile cord blood collection unit (msc128d)',
#  'lansoprazole, amoxicillin and clarithromycin',
#  'nitrofurantoin monohydrate/ macrocrystalline',
#  '.insulin aspart protamine and insulin aspart',
#  'amphetamine extended-release oral suspension',
#  'olmesartan medoxomil and hydrochlorothiazide',
#  'metoprolol succinate and hydrochlorothiazide',
#  'neuromaquel neuroma/anti-inflammatory system',
#  'diatrizoate meglumine and diatrizoate sodium',
#  'abacavir sulfate, lamivudine, and zidovudine',
#  'calcipotriene and betamethasone dipropionate',
#  'sodium sulfacetamide - sulfur cleansing pads',
#  'estrogens, esterified and methyltestosterone',
#  'quinapril hydrochloride/hydrochlorothiazide',
#  'norethindrone and ethinyl estradiol tablets',
#  'metoprolol tartrate and hydrochlorothiazide',
#  'acclean foam fluoride 60 second application',
#  'aspirin and extended - release dipyridamole',
#  'mepivacaine hydrochloride and levonordefrin',
#  'cp2d/as-3 anticoagulant and additive system',
#  'norethindrone acetate and ethinyl estradiol',
#  'esterified estrogens and methyltestosterone',
#  'nitrofurantoin monohydrate/macrocrystalline',
#  'bisoprolol fumarate and hydrochlorothiazide',
#  'clotrimazole and betamethasone dipropionate',
#  'insulin aspart protamine and insulin aspart',
#  'nitrofurantoin monohydrate macrocrystalline',
#  'carisoprodol, aspirin and codeine phosphate',
#  'diclofenac sodium and menthol / camphor gel',
#  'potassium chloride and dextrose monohydrate',
#  'human sputum, bordetella pertussis infected',
#  'triamcinolone acetonide ointment usp, 0.05%',
#  'prednisolone sodium phosphate oral solution',
#  'neomycin sulfate and fluocinolone acetonide',
#  'gentamicin sulfate and prednisolone acetate',
#  'econazole nitrate ,triamcinolone acetonide',
#  'sodium ferric gluconate complex in sucrose',
#  '(ciprofloxacin and fluocinolone acetonide)',
#  'clindamycin phosphate and benzoyl peroxide',
#  'pioglitazone hydrochloride and glimepiride',
#  'sodium citrate and citric acid monohydrate',
#  'multi-vitamin drops with fluoride and iron',
#  'drospirenone and ethinyl estradiol tablets',
#  'travoprost ophthalmic solution usp, 0.004%',
#  'clindamycin phosphate topical solution, 1%',
#  'losartan potassium and hydrochlorothiazide',
#  'nitrofurantoin (monohydrate/macrocrystals)',
#  'sodium sulfacetamide 9% - sulfur 4.5% wash',
#  'aspirin and omeprazole delayed-release tab',
#  'standardized mite dermatophagoides farinae',
#  'orphenadrine citrate, aspirin and caffeine',
#  'adenosine injection, 6mg/2ml (3mg/ml) vial',
#  'vitamin deficiency injectable system - b12',
#  'esterified estrogen and methyltestosterone',
#  'amlodipine, valsartan, hydrochlorothiazide',
#  'promethazine vc with codeine oral solution',
#  'dfs 75mg dr/ms 25%/menth 6%/cap 0.025% pak',
#  'ethynodiol diacetate and ethinyl estradiol',
#  'lisinopril and hydrochlorothiazide tablets',
#  'chlorhexidine gluconate surgical combo kit',
#  'moxifloxacin hydrochloride tablets, 400 mg',
#  'tigan(r) (trimethobenzamide hydrochloride)',
#  'clindamycin phoaphate topical solution, 1%',
#  'ddorzolamide hydrochloride timolol maleate',
#  'sodium sulfacetamide 10 sulfur 2 cleanser',
#  'depo-medrol, lidocaine, isopropyl alcohol',
#  'ertugliflozin and metformin hydrochloride',
#  'sodium sulfacetamide 10 sulfur 5 cleanser',
#  'ipratropium bromide and albuterol sulfate',
#  'azilsartan kamedoxomil and chlorthalidone',
#  'tazobactam sodium and piperacillin sodium',
#  'oseltamivir phosphate for oral suspension',
#  'elagolix and estradiol and norethisterone',
#  'calcipotriene, betamethasone dipropionate',
#  'canagliflozin and metformin hydrochloride',
#  'desloratadine and pseudoephedrine sulfate',
#  'aclidinium bromide and formoterol fumarte',
#  '011054 niacinamide 4% / spironolactone 5%',
#  'clobetasol propionate ointment usp, 0.05%',
#  'oxycodone hydrochloride and acetaminophen',
#  'nitroglycerin transdermal infusion system',
#  'dextroamphetamine sulfateextended-release',
#  'dorzolamide hydrochloride-timolol maleate',
#  'quinapril and hydrochlorothiazide 20/12.5',
#  'sodium sulfacetamide 9.8% and sulfur 4.8%',
#  'polyethylene glycol-3350 and electrolytes',
#  'anas barbarie hepatis et cordis extractum',
#  'sofosbuvir, velpatasvir, and voxilaprevir',
#  'house dust mite, dermatophagoides farinae',
#  'sumatriptan succinate and naproxen sodium',
#  'fosinopril sodium and hydrochlorothiazide',
#  'segesterone acetate and ethinyl estradiol',
#  'nitroglycerin transdermal delivery system',
#  'enalapril maleate and hydrochlorothiazide',
#  'aspirin and extended-release dipyridamole',
#  'coagulation factor viia recombinant human',
#  'empagliflozin and metformin hydrochloride',
#  'dorzolamide hydrochloride timolol maletae',
#  'healthy start weight and appetite support',
#  'technetium tc 99m-labeled red blood cells',
#  'polymyxin b sulfate, trimethoprim sulfate',
#  'bupivacaine hydrochloride and epinephrine',
#  'human albumin microspheres and perflutren',
#  'dapagliflozin and metformin hydrochloride',
#  'piperacillin sodium and tazobactam sodium',
#  'sodium fluoride1.1%, potassium nitrate 5%',
#  'lithium carbonate extended-release tablet',
#  'quinapril and hydrochlorothiazide 10/12.5',
#  'prenatal with ferrous fum and folic acid',
#  'varicella zoster immune globulin (human)',
#  'fluocinonide topical solution usp, 0.05%',
#  'trandolapril and verapamil hydrochloride',
#  'methoxy polyethylene glycol-epoetin beta',
#  'esmolol hydrochloride in sodium chloride',
#  'metformin hydrochloride extended release',
#  'hydroquinone, octinoxate, and oxybenzone',
#  'vigabatrin for oral solution usp, 500 mg',
#  'dextrose monohydrate and sodium chloride',
#  'esterified estrogens, methyltestosterone',
#  'ciprofloxacin and fluocinolone acetonide',
#  'sodium phenylacetate and sodium benzoate',
#  'hydroquinone, octinoxate, and zinc oxide',
#  'sodium phosphate, monobasic, monohydrate',
#  'anticoagulant citrate phosphate dextrose',
#  'haemonetics anticoagulant sodium citrate',
#  'clonidine hydrochloride extended-release',
#  'asprin and extended-release dipyridamole',
#  'hydrocodone bitartrate and acetaminophen',
#  'duloxetine hydrochloride delayed release',
#  'potassium chloride, dextrose monohydrate',
#  'olmesartan medoxomil-hydrochlorothiazide',
#  'hamamelis virginiana root bark/stem bark',
#  'tramadol hydrochloride and acetaminophen',
#  'lidocaine hcl and hydrocortisone acetate',
#  'bupropion hydrochloride extended release',
#  'bacitracin zinc and polymyxin b sulfates',
#  'pioglitazone and metformin hydrochloride',
#  'nitrofurantoin monohydrate/macrocrystals',
#  '011312 niacinamide 4% / tazarotene 0.05%',
#  '011010 niacinamide 4% / tretinoin 0.025%',
#  '011013 niacinamide 4% / tretinoin 0.025%',
#  'sodium sulfacetamide and sulfur cleanser',
#  'chlorhexidine gluconate 0.12% oral rinse',
#  'pioglitazole and metformin hydrochloride',
#  'dutasteride and tamsulosin hydrochloride',
#  'amlodipine and benazepril hydrochloride',
#  'quinapril and hydrochlorothiazide 20/25',
#  'bacitracin zinc and polymyxin b sulfate',
#  'orphenadrine citrate, aspirin, caffeine',
#  'omeprazole, clarithromycin, amoxicillin',
#  'bupivacaine hydrochloride with dextrose',
#  'sitagliptin and metformin hydrochloride',
#  'hydroquinone, octisalate and zinc oxide',
#  'norethindrone acetate/ethinyl estradiol',
#  'standardized kentucky blue (june) grass',
#  'sodium fluoride 5000 ppm enamel protect',
#  'olanzapine and fluoxetine hydrochloride',
#  'hydroquinone, octinoxate and zinc oxide',
#  'saxagliptin and metformin hydrochloride',
#  'clindamycin phosphate, benzoyl peroxide',
#  'immune globulin intravenous (human) 10%',
#  'sumatriptan succinate, camphor, menthol',
#  'phenobarbital with belladonna alkaloids',
#  'dfs 1.5%/ms 25%/menth 6%/cap 0.025% pak',
#  '011020 niacinamide 4% / tretinoin 0.05%',
#  'lidocaine hydrochloride and epinephrine',
#  '011021 niacinamide 4% / tretinoin 0.05%',
#  'sevelamer carbonate for oral suspension',
#  'hydrocortisone, hydroquinone, tretinoin',
#  'butalbital, acetaminophen, and caffeine',
#  'human hepatitis b virus immune globulin',
#  'emtricitabine and tenofovir alafenamide',
#  'hydroquinone, octinoxate,and zinc oxide',
#  'linagliptin and metformin hydrochloride',
#  'beclomethasone dipropionate monohydrate',
#  'articaine hydrochloride and epinephrine',
#  'atnaa atropine and pralidoxime chloride',
#  'hydrocortisone and iodochlorhydroxyquin',
#  'pall sterile cord blood collection unit',
#  'toxycology medicated collection system',
#  'clobetasol propionate cream usp, 0.05%',
#  'cynanchum vincetoxicum root and sulfur',
#  'buprenorphine hydrochloride sublingual',
#  'butalbital, acetaminophen and caffeine',
#  'glycopyrrolate and formoterol fumarate',
#  'cetirizine hydrochloride oral solution',
#  'atovaquone and proguanil hydrochloride',
#  'prevident 5000 booster plus fruitastic',
#  'empagliflozin, metformin hydrochloride',
#  'sodium sulfacetamide 9.8%, sulfur 4.8%',
#  'alogliptin and metformin hydrochloride',
#  'lidocaine hcl - hydrocortisone acetate',
#  'sodium sulfacetamide 9 sulfur 4.5 wash',
#  'positive skin test control - histamine',
#  'alendronate sodium and cholecalciferol',
#  'previddent 5000 booster plus spearmint',
#  'tuberculin purified protein derivative',
#  'vaprisol dextrose in plastic container',
#  'sodium chloride and potassium chloride',
#  'spironolactone and hydrochlorothiazide',
#  'ampicillin sodium and sulbactam sodium',
#  'hydroxyethyl starch in sodium chloride',
#  'certa dose epinephrine convenience kit',
#  'carbon dioxide-oxygen-nitrogen mixture',
#  'piperacillin sodium, tazobactam sodium',
#  'dexamethasone phosphate - moxifloxacin',
#  'cimetidine hydrochloride oral solution',
#  'travoprost ophthalmic solution, 0.004%',
#  'hydrocodone bitartrate and guaifenesin',
#  'exact-rx sodium sulfacetamide wash 10%',
#  '(daunorubicin and cytarabine) liposome',
#  'anticoagulant citrate dextrose a acd-a',
#  'elexacaftor, tezacaftor, and ivacaftor',
#  'potassium chloride and sodium chloride',
#  'sodium sulfacetamide 10 sulfur 2 cream',
#  'oxymetazoline hydrochloride ophthalmic',
#  'hydrocodone bitartrate, acetaminophen',
#  'phenolsulfonic acid and sulfuric acid',
#  'metformin hydrochloride oral solution',
#  'tolterodine tartrate extended release',
#  'sodium fluoride and hydrofluoric acid',
#  'medicated buccal dna collection kit 2',
#  'potassium tetrachloroaurate dihydrate',
#  'piperacillin sodium,tazobactam sodium',
#  'quinapril hcl and hydrochlorothiazide',
#  'dextrose monohydrate, sodium chloride',
#  'glyburide and metformin hydrochloride',
#  'orphenadrine citrate aspirin caffeine',
#  'bupivacaine hydrochloride in dextrose',
#  'glipizide and metformin hydrochloride',
#  'halobetasol propionate and tazarotene',
#  'clotrimazole topical solution usp, 1%',
#  'caffeine, green tea, american ginseng',
#  'levophed(r) norepinephrine bitartrate',
#  'peg-3350, electrolytes, and ascorbate',
#  'amoxicillin and clavulanate potassium',
#  'brimonidine tartrate, timolol maleate',
#  'hydrocortisone acetate, pramoxine hcl',
#  'fluticasone propionate and salmeterol',
#  'sodium nitrite and sodium thiosulfate',
#  'sodium phenylbutyrate tablets, 500 mg',
#  'oxycodone hydrochloride oral solution',
#  'gentamicin sulfate in sodium chloride',
#  'acd blood-pack units (pl 146 plastic)',
#  'potassium chloride in sodium chloride',
#  'anticoagulant sodium citrate solution',
#  'sus scrofa pituitary gland, posterior',
#  'sodium sulfacetamide 8% and sulfur 4%',
#  'sodium fluoride and potassium nitrate',
#  '6% hetastarch in 0.9% sodium chloride',
#  'valganciclovir hydrochloride for oral',
#  'marcaine, lidocaine, povidone iodine',
#  'hydrocodone bitartrate and ibuprofen',
#  'promethazine, phenylephrine, codeine',
#  'polymyxin b sulfate and trimethoprim',
#  'butalbital and acetaminophen tablets',
#  'hydrocortisone acetate pramoxine hcl',
#  'collagenase clostridium histolyticum',
#  'loteprednol etabonate and tobramycin',
#  'air polymer-type a intrauterine foam',
#  'norelgestromin and ethinyl estradiol',
#  'tacrolimus extended-release capsules',
#  'paroxetine hydrochloride hemihydrate',
#  'hyoscyamine sulfate extended-release',
#  'butalbita,acetaminophen and caffeine',
#  'abacavir , lamivudine and zidovudine',
#  '011504 dapsone 8.5% / niacinamide 4%',
#  'levonorgestrel and ethinyl estradiol',
#  'acetic acid and oxyquinoline sulfate',
#  'ciprofloxacin hydrochloride solution',
#  'diclofenac sodium, isopropyl alcohol',
#  'anticoagulant citrate dextrose (acd)',
#  'obagi c rx system c clarifying serum',
#  'clindamycin and benzoyl peroxide gel',
#  'premasol - sulfite-free (amino acid)',
#  'benzocaine, tetracaine hydrochloride',
#  'potassium chloride for oral solution',
#  'norelgestromin and ethinly estradiol',
#  'lorcaserin hydrochloride hemihydrate',
#  'triamcinolone acetonide, dimethicone',
#  'ethinyl estradiol and levonorgestrel',
#  'levalbuterol tartrate hfa inhalation',
#  'dobutamine hydrochloride in dextrose',
#  'lidocaine hydrochloride and dextrose',
#  'nystatin and triamcinolone acetonide',
#  'olodaterol respimat inhalation spray',
#  'pediatric infuvite multiple vitamins',
#  'flor-opal sustained-release fluoride',
#  'lisinopril with hydrochlorothiazide',
#  'methylprednisolone sodium succinate',
#  'diclofenac sodium, kinesiology tape',
#  'bivalirudin in 0.9% sodium chloride',
#  'adapalene and benzoyl peroxide swab',
#  'triamcinolone acetonide, ciclopirox',
#  'potassium chloride extended-release',
#  'naproxen and esomeprazole magnesium',
#  'sodium sulfacetamide 10%, sulfur 2%',
#  'hydrochlorothiazide and triamterene',
#  'dorzolamide hcl and timolol maleate',
#  'cyclosporine/chondroitin sulfate pf',
#  'telmisartan and hydrochlorothiazide',
#  ...]

# %% [markdown]
# # Indication of drugs

# %%
ind_df1 = pd.read_csv('/Users/souravsingh/Documents/NER/Annotation_Data/MeddraHLT.csv')
ind_df2 = pd.read_csv('/Users/souravsingh/Documents/NER/Annotation_Data/MeddraLLT.csv')
# ind_df3 = pd.read_csv('/Users/souravsingh/Documents/NER/Annotation_Data/MeddraPT.csv')

# %%
#remove NAN values from indication name
ind_df1.dropna(subset = ['Name'], inplace=True)
ind_df2.dropna(subset = ['Name'], inplace=True)
# ind_df3.dropna(subset = ['Name'], inplace=True)

# %%
# convert the dataframe column to list
ind_df1_list = ind_df1['Name'].to_list()
ind_df2_list = ind_df2['Name'].to_list()
# ind_df3_list = ind_df3['Name'].to_list()

# %%
# create a list of all indication 
ind_list =[]
ind_list.extend(ind_df1_list)
ind_list.extend(ind_df2_list)
# ind_list.extend(ind_df3_list)

# %%
indicationList = list(map(str.strip, ind_list))
print('Length of Indication list before removing duplicates : {}'.format(len(indicationList)))
indicationList = list(map(lambda x: x.lower(), indicationList))
indicationList =set(indicationList)


indicationList =list(indicationList)
print('Length of Indication list After removing duplicates : {}'.format(len(indicationList)))
# Out:
# Length of Indication list before removing duplicates : 84320
# Length of Indication list After removing duplicates : 84320

# %%
## remove stopwords from the list if any
filtered_words = list(filter(lambda word: word not in stopwords.words('english'), indicationList))

indicationList = filtered_words

# %% [markdown]
# # remove unwanted words

# %%
unwanted_words = ['surgery', 'chemotherapy','urine','culture','escherichia coli','lead']

# %%
## remove stopwords from the list if any
filtered_words = list(filter(lambda word: word not in unwanted_words, indicationList))

indicationList = filtered_words

# %%
## sort the list based on the length of the element in descending order
indicationList.sort(key=len, reverse=True)

# %%
indicationList
# Out:
# ['other cardiovascular diseases of mother complicating pregnancy, childbirth, or the puerperium, unspe',
#  'other specified infectious and parasitic diseases of mother, with delivery, with mention of postpart',
#  'infections of genitourinary tract in pregnancy, with delivery, with mention of postpartum complicati',
#  'osteoarthrosis, localized, not specified whether primary or secondary, involving other specified sit',
#  "arthropathy involving other specified sites associated with reiter's disease and nonspecific urethri",
#  'other nonspecific abnormal results of function studies of peripheral nervous system and special sens',
#  'syphilis of mother, complicating pregnancy, childbirth, or the puerperium, unspecified as to episode',
#  'arthropathy involving pelvic region and thigh associated with other infectious and parasitic disease',
#  'other and unspecified malignant neoplasms of lymphoid and histiocytic tissue, unspec extranodal site',
#  'human immunodeficiency virus, type 2 infection in conditions classified elsewhere and of unspec site',
#  'deep transverse arrest and persistent occipitoposterior posn or occipitoanterior posn dur lab or del',
#  'superficial foreign body (splinter) of other, multiple, and unspec sites w/o mow and w/o ment of inf',
#  'diffuse large cell lymphoma (peripheral t-cell lymphoma unspecified) (working formulation) recurrent',
#  'open fos or face with oth bones with subarac, sub/extradural hem, with state of consciousness unspec',
#  'other viral diseases of mother, complicating pregnancy, childbirth, or the puerperium, unspecified a',
#  'acute peptic ulcer of unspecified site with hemorrhage and perforation, without mention of obstructi',
#  'unspecified pulmonary tuberculosis, bacteriological or histological examination unknown (at present)',
#  'bone and joint disorders of back, pelvis, and lower limbs of mother, complicating pregnancy, childbi',
#  'other malpresentation, malposition, and disproportion during labor and delivery affecting fetus or n',
#  'nephritis and nephropathy, not spec as acute or chronic, with lesion of rapidly progressive glomneph',
#  'large cell immunoblastic lymphoma (angioimmunoblastic t-cell lymphoma) (working formulation) stage i',
#  'diffuse large cell lymphoma (peripheral t-cell lymphoma unspecified) (working formulation) stage iii',
#  'other abnorm in shape or pos of gravid uterus and of neighb struct, deliv, with mentof postpart comp',
#  'clo fos or face & oth bones, with intcran inj of oth & unspec nature, with prol loc and rtrn to pecl',
#  'small cleaved follicular cell lymphoma (mantle cell lymphoma) (lukes-collins classification) stage i',
#  'pre-eclampsia or eclampsia superimposed on pre-existing hypertension, complicating pregnancy, childb',
#  'suspec damage to fetus from oth disease in the mother, affect manag of mother, antepart cond or comp',
#  'tuberculosis of mother, complicating pregnancy, childbirth, or the puerperium, unspecified as to epi',
#  'diffuse small cleaved cell lymphoma (adult t-cell lymphoma/leukaemia) (working formulation) stage ii',
#  'thyroid dysfunction of mother, complicating pregnancy, childbirth, or the puerperium, unspecified as',
#  'osteoarthrosis, localized, not specified whether primary or secondary, involving pelvic region and t',
#  'longitudinal deficiency, phalanges of foot, complete or partial (with or w/o distal def, incomplete)',
#  'longitudinal deficiency, tibiofibular, complete or partial (with or w/o distal deficiencies, incomp)',
#  'malignant neoplasm of other specified sites of gallbladder and extrahepatic bile ducts nonresectable',
#  'mental disorders of mother, complicating pregnancy, childbirth, or the puerperium, unspecified as to',
#  'superficial foreign body (splinter) of elbow, forearm, and wrist, without major open wound, infected',
#  'mechanical complication of cardiac device, implant, and graft due to automatic implantable cardiac d',
#  'other current conditions in the mother classifiable elsewhere, but complicating pregnancy, childbirt',
#  'benign essential hypertension complicating pregnancy, childbirth, and the puerperium, unspecified as',
#  'open fracture of vault of skull without mention of intracranial injury, with concussion, unspecified',
#  'unspecified tuberculosis of central nervous system, tubercle bacilli found (in sputum) by microscopy',
#  'other and unspecified superficial injury of hip, thigh, leg, and ankle, without mention of infection',
#  'longitudinal deficiency, phalanges of hand, complete or partial (with or w/o distal def, incomplete)',
#  'varicose veins of vulva and perineum, with delivery, with or without mention of antepartum condition',
#  'unspecified infection or infestation of mother, with delivery, with mention of postpartum complicati',
#  'deep necro of under tiss, burn (dtd) of eye (with oth parts of face, head, & neck), w/o ment of lobp',
#  'clo fos or face with oth bones, with intcran inj of oth and unspec nature, with state of cons unspec',
#  'unspecified infection or infestation of mother, complicating pregnancy, childbirth, or the puerperiu',
#  'twin preg with fetal loss and retention of one fetus,delivered, with or w/o mention of antepart cond',
#  'other known or suspected fetal abnormality, not elsewhere classified, affecting management of mother',
#  'clo fos or face & oth bones, with intcran inj of oth & unspec nature, with prol loc,w/o rtrn to pecl',
#  'clo fos or face with oth bones, with intcran inj of oth and unspec nature, with prol loc, w/o return',
#  'tuberculous abscess of spinal cord, bacteriological or histological examination unknown (at present)',
#  'unspecified umbilical cord complication during labor and delivery, unspecified as to episode of care',
#  'hypertension secondary to renal disease, complicating pregnancy, childbirth, and the puerperium, uns',
#  'acute peptic ulcer of unspecified site without mention of hemorrhage and perforation, without mentio',
#  'chronic or unspecified peptic ulcer of unspec site with hemorrhage and perforation, w/o ment of obst',
#  'diffuse large cell lymphoma (high grade b-cell lymphoma burkitt-like lymphoma) (working formulation)',
#  'pre-eclampsia or eclampsia superimposed on pre-existing hypertension, with delivery, with mention of',
#  'retained portions of placenta or membranes, without hemorrhage, postpartum condition or complication',
#  'suspected damage to fetus from other disease in the mother, affecting manag of mother, with delivery',
#  'deep necro of under tiss due to burn (dtd) of two or more digits of hand, not includ thumb, with lof',
#  'open fos or face with oth bones, with intcran inj of oth and unspec nature, prol loc, w/o rtrn to pe',
#  'other venereal diseases of mother, complicating pregnancy, childbirth, or the puerperium, unspecifie',
#  'diffuse small cleaved cell lymphoma (adult t-cell lymphoma/leukaemia) (working formulation) stage iv',
#  'diffuse mixed small and large cell lymphoma (angiocentric lymphoma) (working formulation) refractory',
#  'other nephritis and nephropathy, not specified as acute or chronic, in diseases classified elsewhere',
#  'deep necrosis of underlying tissues due to burn (deep third degree) of forearm, with loss of forearm',
#  'other obstetrical pulmonary embolism, with delivery, with or without mention of antepartum condition',
#  'open fracture of base of skull without mention of intracranial injury, with no loss of consciousness',
#  'unspecified problem associated with amniotic cavity and membranes, unspecified as to episode of care',
#  'tuberculosis of lung, infiltrative, bacteriological or histological examination unknown (at present)',
#  'unspecified hypertension complicating pregnancy, childbirth, or the puerperium, unspecified as to ep',
#  'suspected damage to fetus from viral disease in the mother, affecting manag of mother, with delivery',
#  'nephritis and nephropathy, not specified as acute or chronic, with lesion of renal cortical necrosis',
#  'nephritis and nephropathy, not specified as acute or chronic, with lesion of membranoprolif glomneph',
#  'other specified infectious and parasitic diseases complicating pregnancy, childbirth, or the puerper',
#  'other spec infect and parasit diseases of mother, comp preg, c/birth, or the puerp, unspec as to eoc',
#  'shock during or following labor and delivery, with delivery, without mention of antepartum condition',
#  'osteoarthrosis involving or with mention of more than one site, but not specified as generalized, an',
#  'chronic peptic ulcer of unspecified site w/o mention of haemorrhage or perforation, with obstruction',
#  'diabetes mellitus of mother, complicating pregnancy, childbirth, or the puerperium, unspecified as t',
#  'chronic duodenal ulcer without mention of haemorrhage or perforation, without mention of obstruction',
#  'edema or excessive weight gain in pregnancy, with delivery, with mention of postpartum complication.',
#  'hereditary disease in family possibly affecting fetus, affecting management of mother, with delivery',
#  'chronic or unspecified peptic ulcer of unspecified site with perforation, w/o mention of obstruction',
#  'oth and unspec disorder of breast assoc with childbirth, delivered, with or w/o ment of antepar cond',
#  'superficial foreign body of hand(s) except finger(s) alone w/o major open wound and w/o ment of infe',
#  'open fracture of base of skull with cerebral laceration and contusion, with no loss of consciousness',
#  'deep necro of underlying tiss due to burn (dtd) of upper limb, except wrist and hand w/o ment of lob',
#  'open fracture of vault of skull with cerebral laceration and contusion, with concussion, unspecified',
#  'subarachnoid hemorrhage following injury, with open intracranial wound, with concussion, unspecified',
#  'duodenal ulcer, unspec as acute or chronic, w/o ment of haemorrhage or perforation, with obstruction',
#  'open fos or face with oth bones, with intcran inj of oth and unspec nature, with prol loc and return',
#  'acute peptic ulcer of unspecified site without mention of hemorrhage and perforation, with obstructi',
#  'other and unspec cord entanglement, w/o ment of compress, comp labor and delivery, unspec as to eoc',
#  'clo fos or face with oth bones, with intcran inj of oth and unspec nature, with prol loc and return',
#  'b-cell chronic lymphocytic leukaemia/prolymphocytic leukaemia/small lymphocytic lymphoma refractory',
#  'gastric ulcer, unspec as acute or chronic, w/o ment of haemorrhage or perforation, with obstruction',
#  'extradural hemorrhage following injury, with open intracranial wound, with no loss of consciousness',
#  'nephritis and nephropathy, not specified as acute or chronic, with lesion of proliferative glomneph',
#  'gastrojejunal ulcer, unspecified as acute or chronic, without mention of haemorrhage or perforation',
#  'unspec comp of anesthesia or oth sedat in labor and delivery, delivered, with ment of postpart comp',
#  'small noncleaved follicular center cell lymphoma (high grade b-cell burkitt-like lymphoma) stage iv',
#  'osteoarthrosis involving more than one site, but not spec as generalized, and involving unspec site',
#  'hypertensive heart and renal disease, unspec, w/o ment of congestive heart failure or renal failure',
#  'chronic gastric ulcer without mention of haemorrhage or perforation, without mention of obstruction',
#  'cerebellar or brain stem contu w/o ment of open intcran wound, with prolonged loc, w/o rtrn to pecl',
#  'chronic peptic ulcer of unspecified site w/o mention of hemorrhage or perforation, with obstruction',
#  'burn (any degree) involving less than 10 % of body surface with tdb of less than 10 % or unspec amt',
#  'open fos or face with oth bones, with intcran inj of oth and unspec nature, with loc of unspec dura',
#  'other and unspecified malignant neoplasms of lymphoid and histiocytic tissue inv head/neck lymph ns',
#  'diffuse large cell lymphoma (peripheral t-cell lymphoma unspecified) (working formulation) stage iv',
#  'diffuse small cleaved cell lymphoma (adult t-cell lymphoma/leukemia) (working formulation) stage iv',
#  'diffuse mixed small and large cell lymphoma (angiocentric lymphoma) (working formulation) recurrent',
#  'oth and unspec intcran hem following inj, w/o ment of open intcran wound, with state of cons unspec',
#  'thyrotoxicosis without mention of goiter or other cause, with mention of thyrotoxic crisis or storm',
#  'diffuse mixed small and large cell lymphoma (adult t-cell lymphoma/leukaemia) (working formulation)',
#  'other and unspecified cerebral laceration and contusion, without mention of open intracranial wound',
#  'drug dependence of mother, complicating pregnancy, childbirth, or the puerperium, unspecified as to',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukaemia) (lukes-collins classification) refractory',
#  'large cell immunoblastic lymphoma (anaplastic large cell lymphoma t- and null-cell types) recurrent',
#  'proteus (mirabilis) (morganii) infection in conditions classified elsewhere and of unspecified site',
#  'longitudinal deficiency, fibular, complete or partial (with or w/o distal deficiencies, incomplete)',
#  'superficial foreign body of face, neck and scalp except eye w/o major open wound and w/o mention of',
#  'pre-eclamp/ eclamp superimposed on pre-existing hyperten, with delivery, with ment of postpart comp',
#  'other abnormalities in shape or position of gravid uterus and of neighboring structures, postpartum',
#  'other and unspecified malignant neoplasms of lymphoid and histiocytic tissue inv abdominal lymph ns',
#  'bone and (jd) of back, pelvis, and lower limbs of mother, with delivery, with ment of postpart comp',
#  'small noncleaved follicular center cell lymphoma (high grade b-cell burkitt-like lymphoma) stage ii',
#  'deep transverse arrest and persistent occipitoposterior position, unspecified as to episode of care',
#  'duodenal ulcer, unspec as acute or chronic, w/o ment of hemorrhage or perforation, with obstruction',
#  'multiple fracts involv both lwr limbs, lwr with upr limb, and lwr limb with rib and sternum, closed',
#  'longitudinal deficiency, humeral, complete or partial (with or w/o distal deficiencies, incomplete)',
#  'chronic or unspecified gastric ulcer with hemorrhage and perforation,without mention of obstruction',
#  'subarachnoid, subdural, and extradural haemorrhage, following injury, w/o ment open intracran wound',
#  'nonpurulent mastitis associated with childbirth, delivered, with mention of postpartum complication',
#  'thyrotoxicosis without mention of goiter or other cause, and w/o ment of thyrotoxic crisis or storm',
#  'open fracture of base of skull without mention of intracranial injury, with concussion, unspecified',
#  'cerebellar or brain stem contu w/o ment of open intcran wound, with prol loss cons and rtrn to pecl',
#  'longitudinal deficiency, femoral, complete or partial (with or w/o distal deficiencies, incomplete)',
#  'open fracture of base of skull with cerebral laceration and contusion, with concussion, unspecified',
#  'deep necrosis of underlying tissues due to burns (dtd) of multiple specified sites w/o mention lobp',
#  'other abnormalities in shape or position of gravid uterus and of neighboring structures, antepartum',
#  'human immunodeficiency virus, type 2 infection in conditions classified elsewhere and of unspec sit',
#  'arthropathy involving other specified sites associated with other infectious and parasitic diseases',
#  'closed frac of vos with intcran inj of oth and unspec nature, with prolonged loc and return to pecl',
#  'cerebellar or brain stem lacer w/o ment of open intcran wound, with prolonged loc, w/o rtrn to pecl',
#  'varicose veins of legs complicating pregnancy and the puerperium, unspecified as to episode of care',
#  'diffuse large cell lymphoma (peripheral t-cell lymphoma unspecified) (working formulation) stage ii',
#  'other specified infectious and parasitic diseases of mother, complicating pregnancy, childbirth, or',
#  'osteoarthrosis, localized, not spec whether primary or secondary, involving pelvic region and thigh',
#  'other and unspecified superficial injury of elbow, forearm, and wrist, without mention of infection',
#  'chronic duodenal ulcer without mention of hemorrhage or perforation, without mention of obstruction',
#  'cardiac comps of anesthesia or other sedat in labor and delivery, deliv, with ment of postpart comp',
#  'rubella of mother, complicating pregnancy, childbirth, or the puerperium, unspecified as to episode',
#  'lymphoblastic lymphoma (precursor t-lymphoblastic lymphoma/leukaemia) (working formulation) stage i',
#  'blisters with epidermal loss due to burn (second degree) of chest wall, excluding breast and nipple',
#  'diffuse small cleaved cell lymphoma (adult t-cell lymphoma/leukaemia) (working formulation) stage i',
#  'other pre-existing hypertension complicating pregnancy, childbirth, and the puerperium, unspecified',
#  'diffuse mixed small and large cell lymphoma (angiocentric lymphoma) (working formulation) stage iii',
#  'open fos or face & oth bones, with intcran inj of oth and unspec nature, prol loc, w/o rtrn to pecl',
#  'large cell immunoblastic lymphoma (anaplastic large cell lymphoma t- and null-cell types) stage iii',
#  'diffuse small cleaved cell lymphoma (adult t-cell lymphoma/leukemia) (working formulation) stage ii',
#  'other specified non-arthropod-borne viral diseases of central nervous system central nervous system',
#  'deep necrosis of underlying tissues due to burn (deep third degree) of lip(s), with loss of lip(s)',
#  'extradural hemorrhage following injury, with open intracranial wound, with concussion, unspecified',
#  'acute reaction to foreign substance accidentally left during a procedure, not elsewhere classified',
#  'hypertensive heart and renal disease, unspecified, with congestive heart failure and renal failure',
#  'hered disease in family possibly affecting fetus, affecting manag of mother, antepart cond or comp',
#  'large cell immunoblastic lymphoma (anaplastic large cell lymphoma t- and null-cell types) stage iv',
#  'other specified complications of pregnancy, with delivery, with mention of postpartum complication',
#  'quad preg with fetal loss and reten of one or more fetus, deliv, with or w/o ment of antepart cond',
#  'b-cell chronic lymphocytic leukaemia/prolymphocytic leukaemia/small lymphocytic lymphoma stage iii',
#  'unspecified venous complication of pregnancy and the puerperium, unspecified as to episode of care',
#  'deep necro of underlying tissues due to burns (dtd) of upper limb, except wrist and hand with lobp',
#  'major depressive disorder, recurrent episode, severe degree, specified as with psychotic behaviour',
#  'tuberculosis of vertebral column, bacteriological or histological examination unknown (at present)',
#  'other and unspecified malignant neoplasms of lymphoid and histiocytic tissue inv inguinal lymph ns',
#  'oth and unspec cerebral lacer and contu, w/o ment of open intcran wound, with state of cons unspec',
#  'other and unspecified malignant neoplasms of lymphoid and histiocytic tissue inv axillary lymph ns',
#  'other comps of anesthesia or oth sedat in labor and delivery, delivered, with men of postpart comp',
#  'cortex (cerebral) laceration with open intracranial wound, with state of consciousness unspecified',
#  'lymphoblastic lymphoma (precursor t-lymphoblastic lymphoma/leukemia) (working formulation) stage i',
#  'other indications for care or intervention related to labor and delivery, not elsewhere classified',
#  'hypertensive heart and renal disease, benign, without mention of congestive heart or renal failure',
#  'tuberculous pneumonia (any form), bacteriological or histological examination unknown (at present)',
#  'full-thickness skin loss due to burn (third degree nos) of chest wall, excluding breast and nipple',
#  'tuberculosis of unspecified bones and joints, bacteriological or histological examination not done',
#  'diffuse mixed small and large cell lymphoma (angiocentric lymphoma) (working formulation) stage iv',
#  'diffuse mixed small and large cell lymphoma (angiocentric lymphoma) (working formulation) stage ii',
#  'clo fos or face with oth bones, with intcran inj of oth and unspec nature, with concussion, unspec',
#  'clo fos or face with oth bones, with intcran inj of oth and unspec nature, with loc of unspec dura',
#  'deep necrosis of underlying tissues due to burn (deep third degree) of breast, with loss of breast',
#  'b-cell chronic lymphocytic leukaemia/prolymphocytic leukaemia/small lymphocytic lymphoma recurrent',
#  'longitudinal deficiency, radioulnar, complete or partial (with or w/o distal deficiencies, incomp)',
#  'deep necrosis of underlying tissues due to burn (deep third degree) of axilla, with loss of axilla',
#  'closed frac of bos with intcran inj of oth and unspec nature, with prolonged loc, w/o rtrn to pecl',
#  'gastrojejunal ulcer, unspecified as acute or chronic, without mention of hemorrhage or perforation',
#  'blisters with epidermal loss due to burn (second degree) of multiple sites of wrist(s) and hand(s)',
#  'pre-eclamp/eclamp superimp on preexist hyperten, comp preg, c/birth or the puerp, unspec as to eoc',
#  'longitudinal deficiency, carp or metacarp, complete or partial (with or w/o incomp phalangeal def)',
#  'other and unspecified malignant neoplasms of lymphoid and histiocytic tissue inv thoracic lymph ns',
#  'chronic gastric ulcer without mention of hemorrhage or perforation, without mention of obstruction',
#  'other abnormalities in shape or position of gravid uterus and of neighboring structures, delivered',
#  'subdural haemorrhage following injury, with open intracranial wound, with no loss of consciousness',
#  'infections of nipple associated with childbirth, delivered with mention of postpartum complication',
#  'diffuse large cell lymphoma (peripheral t-cell lymphoma unspecified) (working formulation) stage i',
#  'other and unspec morphological and functional abnormalities of placenta affecting fetus or newborn',
#  'oth and unspec intcran hem following inj, with open intcran wound, with prol loc, w/o rtrn to pecl',
#  'other and unspec cord entanglement, w/o mention of compression, comp labor and delivery, delivered',
#  'closed frac of vos with intcran inj of oth and unspec nature, with prolonged loc, w/o rtrn to pecl',
#  'diffuse mixed small and large cell lymphoma (adult t-cell lymphoma/leukemia) (working formulation)',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukaemia) (lukes-collins classification) recurrent',
#  't-immunoblastic lymphoma (peripheral t-cell lymphoma unspecified) (kiel classification) refractory',
#  'syphilis of mother, complicating pregnancy, with delivery, with mention of postpartum complication',
#  'small noncleaved follicular center cell lymphoma (high grade b-cell burkitt-like lymphoma) stage i',
#  'duodenal ulcer, unspec as acute or chronic, w/o hemorrhage or perforation, w/o ment of obstruction',
#  'tuberculous pleurisy in primary progressive tuberculosis, tubercle bacilli in sputum by microscopy',
#  'oth & unspec intcran hem following inj. w/o ment of open intcran wound, prol loc, w/o rtrn to pecl',
#  'other and unspec abnormality of organs and soft tissues of pelvis, deliv with mentof postpart comp',
#  'other congenital or acquired abnormality of cervix, unspecified as to episode of care in pregnancy',
#  'large cell immunoblastic lymphoma (diffuse large b-cell lymphoma) (working formulation) refractory',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukemia) (lukes-collins classification) refractory',
#  'trip preg with fetal loss and reten of one or more fetus, deliv, with or w/o ment of antepart cond',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukaemia) (lukes-collins classification) stage iii',
#  'tuberculosis of intestines and mesenteric glands, tubercle bacilli found (in sputum) by microscopy',
#  'cerebellar or brain stem lacer w/o ment of open intcran wound, with prolonged loc and rtrn to pecl',
#  'large cell immunoblastic lymphoma (anaplastic large cell lymphoma t- and null-cell types) stage ii',
#  'centroblastic (monomorphic, polymorphic, and multilobated subtypes) lymphoma (kiel classification)',
#  'partial epilepsy, without mention of impairment of consciousness, w/o ment of intractable epilepsy',
#  'major depressive disorder, recurrent episode, severe degree, without mention of psychotic behavior',
#  'congenital or acquired abnormality of vagina complicating pregnancy, childbirth, or the puerperium',
#  'hypertensive heart and renal disease, malig, w/o ment of congestive heart failure or renal failure',
#  'diffuse small cleaved cell lymphoma (adult t-cell lymphoma/leukemia) (working formulation) stage i',
#  'diffuse small cleaved cell lymphoma (peripheral t-cell lymphoma unspecified) (working formulation)',
#  'gastric ulcer, unspec as acute or chronic, w/o ment of hemorrhage or perforation, with obstruction',
#  'longitudinal deficiency, radial, complete or partial (with or w/o distal deficiencies, incomplete)',
#  'partial epilepsy, without mention of impairment of consciousness w/o ment of intractable epilepsy',
#  'hered disease in family poss affecting fetus, affecting manag of mother, unspec as to eoc in preg',
#  'intcran inj of oth and unspec nature, with open intcran wound, with state of consciousness unspec',
#  'oth and unspec intcran hem following inj, w/o ment of open intcran wound, with loc of unspec dura',
#  'other closed skull fracture with cerebral laceration and contusion, with no loss of consciousness',
#  'insect bite, nonvenomous, of other, multiple, and unspecified sites, without mention of infection',
#  'gastrojejunal ulcer, unspec as acute or chronic, w/o ment of hem or perf, w/o ment of obstruction',
#  'subdural hemorrhage following injury, with open intracranial wound, with no loss of consciousness',
#  'diffuse mixed small and large cell lymphoma (diffuse large b-cell lymphoma) (working formulation)',
#  'erythema nodosum with hypersensitivity reaction in tuberculosis, tubercle bacilli found in sputum',
#  'oth open skull frac with intcran inj of oth and unspec nature, with state of consciousness unspec',
#  'unspecified adverse effect of drug, medicament and biological substance, not elsewhere classified',
#  'acute duodenal ulcer without mention of hemorrhage or perforation, without mention of obstruction',
#  'closed frac of bos with intcran inj of oth and unspec nature, with prolonged loc and rtrn to pecl',
#  'longitudinal deficiency, ulnar, complete or partial (with or w/o distal deficiencies, incomplete)',
#  'other named variants of lymphosarcoma and reticulosarcoma involving lymph nodes of multiple sites',
#  'longitudinal def, tarsals or metatarsals, complete or partial (with or w/o incomp phalangeal def)',
#  'large cell immunoblastic lymphoma (diffuse large b-cell lymphoma) (working formulation) recurrent',
#  'b-cell chronic lymphocytic leukaemia/prolymphocytic leukaemia/small lymphocytic lymphoma stage ii',
#  'traumatic amputation of leg(s) (complete) (partial), unilateral, level not specified, complicated',
#  'malignant neoplasm of other and ill-defined sites within the resp system and intrathoracic organs',
#  'small lymphocytic lymphoma (nodal marginal zone b-cell lymphoma) (working formulation) refractory',
#  't-immunoblastic lymphoma (peripheral t-cell lymphoma unspecified) (kiel classification) recurrent',
#  'laceration of heart with penetration of heart chambers, without mention of open wound into thorax',
#  'b-cell chronic lymphocytic leukaemia/prolymphocytic leukaemia/small lymphocytic lymphoma stage iv',
#  'nonspecific abnormal findings on radiological and other examination of other intrathoracic organs',
#  'open fos or face with oth bones, with oth and unspec intcran hem, with prol loc, w/o rtrn to pecl',
#  "hodgkin's disease, lymphocytic depletion, involving lymph nodes of inguinal region and lower limb",
#  'unspecified disorder of lactation, with delivery, with or without mention of antepartum condition',
#  'closed fractures involving skull or face with other bones, without mention of intracranial injury',
#  'recurrent unilateral or unspecified inguinal hernia with obstruction, without mention of gangrene',
#  'burn (any degree) involving 90 % or more of body surface with tdb of less than 10 % or unspec amt',
#  'diffuse small cleaved cell lymphoma (intestinal t-cell lymphoma) (working formulation) refractory',
#  'closed fos or face with oth bones, w/o ment or intcran inj, with prolonged loc and return to pecl',
#  'b-cell chronic lymphocytic leukemia/prolymphocytic leukemia/small lymphocytic lymphoma refractory',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukemia) (lukes-collins classification) recurrent',
#  'multiple fracts involv both lwr limbs, lwr with upr limb, and lwr limb with rib and sternum, open',
#  'oth & unspec intcran hem following inj, w/o ment of open intcran wound, prol loc and rtrn to pecl',
#  'cerebellar or brain stem lacer w/o ment of open intcran wound, with state of consciousness unspec',
#  'other current conds in the mother classifiable elsewhere, but comp preg, childbirth, or the puerp',
#  'retained portions of placenta or membranes, w/o hemorrhage, delivered, with ment of postpart comp',
#  'diffuse large cell lymphoma (angioimmunoblastic t-cell lymphoma) (working formulation) refractory',
#  'large cell immunoblastic lymphoma (diffuse large b-cell lymphoma) (working formulation) stage iii',
#  'multiple fractures involving both lwr limbs, lwr with upr limb, and lwr limb with rib and sternum',
#  'poisoning by agents primarily affecting skin and mucous memb, ophth, oto/rhin/lary, and den drugs',
#  'congenital or acquired abnormality of vulva complicating pregnancy, childbirth, or the puerperium',
#  'other and unspec superficial injury of other, multiple, and unspec sites w/o mention of infection',
#  'osteoarthrosis, localized, not specified whether primary or secondary, involving unspecified site',
#  'primary tuberculous infection, unspecified type, tubercle bacilli found (in sputum) by microscopy',
#  'tuberculosis of other female genital organs, bacteriological or histological examination not done',
#  'superficial foreign body (splinter) of hand(s) except finger(s) alone w/o major open wound, infec',
#  'open fos or face with oth bones with subarac, sub/extradural hem, with prol loc, w/o rtrn to pecl',
#  'other and unspec cord entanglement, w/o mention of compression, comp labor and delivery, antepart',
#  'chronic or unspecified peptic ulcer of unspecified site with haemorrhage, w/o ment of obstruction',
#  'injury to multiple and unspecified intrathoracic organs without mention of open wound into cavity',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukemia) (lukes-collins classification) stage iii',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukaemia) (lukes-collins classification) stage ii',
#  'longitudinal deficiency, tibia, complete or partial (with or w/o distal deficiencies, incomplete)',
#  'obstruction caused by malposition of foetus at onset of labour, unspecified as to episode of care',
#  'full-thickness skin loss due to burn (third degree nos) of multiple sites of wrist(s) and hand(s)',
#  'superficial foreign body (splinter) of shoulder and upper arm, without major open wound, infected',
#  'diffuse mixed small and large cell lymphoma (angiocentric lymphoma) (working formulation) stage i',
#  'retained portions of placenta or membranes, without hemorrhage, unspecified as to episode of care',
#  'oth and unspec cereb lacer and contu, w/o ment of open intcran wound, with loc of unspec duration',
#  'major depressive disorder, recurrent episode, severe degree, specified as with psychotic behavior',
#  'cortex (cerebral) contusion with open intracranial wound, with state of consciousness unspecified',
#  'other current conds class elsewhere of mother, comp preg, c/birth, or the puerp, unspec as to eoc',
#  'other indications for care or intervention related to labour and delivery and not elsewhere class',
#  'other known or suspected fetal abnormality, nec, affecting manag of mother, antepart cond or comp',
#  'other closed skull fracture without mention of intracranial injury, with no loss of consciousness',
#  'unspecified milary tuberculosis, bacteriological or histological examination unknown (at present)',
#  't-immunoblastic lymphoma (peripheral t-cell lymphoma unspecified) (kiel classification) stage iii',
#  'abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection',
#  'large cell immunoblastic lymphoma (anaplastic large cell lymphoma t- and null-cell types) stage i',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukaemia) (lukes-collins classification) stage iv',
#  'closed fractures involving skull or face with other bones, with cerebral laceration and contusion',
#  'oth and unspec intcran hem following inj, with open intcran wound, with prol loc and rtrn to pecl',
#  'isolated tracheal or bronchial tuberculosis, bacteriological or histological examination not done',
#  'deep necro of under tiss due to burn (dtd) of upper limb, except wrist and hand, w/o ment of lobp',
#  'closed fos or face with oth bones, with cerebral lacer and contu, with prol loc, w/o rtrn to pecl',
#  "arthropathy involving shoulder region associated with reiter's disease and nonspecific urethritis",
#  'diffuse mixed small and large cell lymphoma (lymphoplasmacytoid lymphoma/immunocytoma) refractory',
#  'eclampsia complicating pregnancy, childbirth or the puerperium, unspecified as to episode of care',
#  'shock during or following labor and delivery, with delivery, with or w/o mention of antepart cond',
#  'subdural hem following inj, w/o ment of open intcran wound, with prolonged loc, w/o rtrn to pecl',
#  'open fos or face with oth bones, w/o ment of intcran inj, with prolonged loc, w/o return to pecl',
#  'maternal hypotension syndrome complicating labor and delivery, unspecified as to episode of care',
#  'oth open skull frac with intcran inj of oth and unspec nature, with prol loc, w/o return to pecl',
#  'oth closed skull frac with intcran inj of oth and unspec nature, with prol loc, w/o rtrn to pecl',
#  'closed frac of vos with intcran inj of oth and unspec nature, with state of consciousness unspec',
#  'injury to other and unspecified gastrointestinal sites without mention of open wound into cavity',
#  'acute gastric ulcer without mention of hemorrhage or perforation, without mention of obstruction',
#  'tuberculosis of adrenal glands, bacteriological or histological examination unknown (at present)',
#  'osteoarthrosis, localized, not specified whether primary or secondary, involving shoulder region',
#  'super foreign body (splinter) of face, neck, and scalp except eye, w/o mow and w/o ment of infec',
#  't-immunoblastic lymphoma (peripheral t-cell lymphoma unspecified) (kiel classification) stage iv',
#  't-immunoblastic lymphoma (peripheral t-cell lymphoma unspecified) (lukes-collins classification)',
#  'deep necrosis of underlying tissues due to burn (deep third degree) of ankle, with loss of ankle',
#  'burn (any degree) involving 90 % or more of body surface with tdb of 90% or more of body surface',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukemia) (lukes-collins classification) stage iv',
#  'large cell immunoblastic lymphoma (diffuse large b-cell lymphoma) (working formulation) stage iv',
#  'diffuse small cleaved cell lymphoma (intestinal t-cell lymphoma) (working formulation) recurrent',
#  'small lymphocytic lymphoma (nodal marginal zone b-cell lymphoma) (working formulation) stage iii',
#  't-immunoblastic lymphoma (peripheral t-cell lymphoma unspecified) (kiel classification) stage ii',
#  'diffuse mixed small and large cell lymphoma (lymphoplasmacytoid lymphoma/immunocytoma) stage iii',
#  'blisters with epidermal loss due to burn (second degree) of unspecified site of lower limb (leg)',
#  'closed frac of bos with intcran inj of oth and unspec nature, with state of consciousness unspec',
#  'unspec infection or infestation of mother, comp preg, childbirth, or the puerp, unspec as to eoc',
#  'capsular tears to spleen, w/o major disruption of parenchyma, w/o ment of open wound into cavity',
#  'gastric ulcer, unspec as acute or chronic, w/o ment of hemorrhage or perforation, or obstruction',
#  'isoimmunization from other and unspec blood-group incompat, affecting manag of mother, delivered',
#  'oth and unspec cereb lacer and contu, w/o ment of open intcran wound, prol loc, w/o rtrn to pecl',
#  'open fos or face with oth bones with subarac, sub/extradural hem, with prol loc and rtrn to pecl',
#  'b-cell chronic lymphocytic leukemia/prolymphocytic leukemia/small lymphocytic lymphoma stage iii',
#  'large cell immunoblastic lymphoma (peripheral t-cell lymphoma unspecified) (working formulation)',
#  "arthropathy involving multiple sites associated with reiter's disease and nonspecific urethritis",
#  'open fos or face with oth bones, with intcran inj of oth and unspec nature, state of cons unspec',
#  'edema or excessive weight gain in pregnancy, with delivery, with or w/o ment of antepartum compn',
#  'other closed skull fracture without mention of intracranial injury, with concussion, unspecified',
#  'open fos or face with oth bones, with oth and unspec intcran hem, with prol loc and rtrn to pecl',
#  'extradural hem following inj, w/o ment of open intcran wound, with state of consciousness unspec',
#  'traumatic ampu of arm and hand (complete) (partial), unilat, at or above elbow, w/o ment of comp',
#  'chronic peptic ulcer of unspecified site without mention of hem or perf, w/o ment of obstruction',
#  'chronic or unspecified peptic ulcer of unspecified site with hemorrhage, w/o ment of obstruction',
#  'b-cell chronic lymphocytic leukemia/prolymphocytic leukemia/small lymphocytic lymphoma recurrent',
#  'osteoarthrosis involving or with mention of more than one site, but not specified as generalized',
#  'erythema nodosum with hypersensitivity reaction in tuberculosis, confirmed by animal inoculation',
#  'abscess of breast associated with childbirth, delivered, with mention of postpartum complication',
#  'subdural hemorrhage following injury, with open intracranial wound, with concussion, unspecified',
#  "arthropathy involving pelvic region and thigh associated with reiter's disease and nonspec ureth",
#  'isoimmunization from other and unspec blood-group incompatibility, unspec as to eoc in pregnancy',
#  'clo fos or face with oth bones with subarac, sub/extradural hem, with prol loc, w/o rtrn to pecl',
#  "arthropathy involving ankle and foot associated with reiter's disease and nonspecific urethritis",
#  "hodgkin's disease, lymphocytic-histiocytic predominance involving lymph nodes of multiple sites.",
#  'diffuse mixed small and large cell lymphoma (lymphoplasmacytoid lymphoma/immunocytoma) recurrent',
#  'nephritis and nephropathy, not specified as acute or chronic, with lesion of membranous glomneph',
#  'other closed skull fracture with cerebral laceration and contusion, with concussion, unspecified',
#  'closed fos or face with oth bones, with cerebral lacer and contu, with prol loc and rtrn to pecl',
#  'diffuse large cell lymphoma (angioimmunoblastic t-cell lymphoma) (working formulation) stage iii',
#  'abnormal glucose tolerance of mother, comp pregnancy, childbirth, or the puerp, unspec as to eoc',
#  'other and unspecified superficial injury of shoulder and upper arm, without mention of infection',
#  'unspecified adverse effect of drug, medicinal and biological substance, not elsewhere classified',
#  'small lymphocytic lymphoma (nodal marginal zone b-cell lymphoma) (working formulation) recurrent',
#  'intcran inj of oth and unspec nature, w/o ment of open intcran wound, prol loc, w/o rtrn to pecl',
#  'clo fos or face with oth bones, with oth and unspec intcran hem, with prol loc, w/o rtrn to pecl',
#  'diffuse large cell lymphoma (angioimmunoblastic t-cell lymphoma) (working formulation) recurrent',
#  'superficial foreign body (splinter) of hip, thigh, leg, and ankle, w/o mow and w/o ment of infec',
#  'b-cell chronic lymphocytic leukaemia/prolymphocytic leukaemia/small lymphocytic lymphoma stage i',
#  'malaria of mother, complicating preg, childbirth or the puerperium, unspec as to episode of care',
#  'infect and parasitic cond in the mother classifiable elsewhere, but compg preg, c/birth or puerp',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukemia) (lukes-collins classification) stage ii',
#  'hypertensive heart and renal disease, malignant, with congestive heart failure and renal failure',
#  'nephritis and nephropathy, not spec as acute or chronic, with lesion of renal medullary necrosis',
#  'diffuse small cleaved cell lymphoma (intestinal t-cell lymphoma) (working formulation) stage iii',
#  'deep necro of under tiss, burn (dtd) of two or more digits of hand includ thumb, w/o ment of lof',
#  'large cell immunoblastic lymphoma (diffuse large b-cell lymphoma) (working formulation) stage ii',
#  't-immunoblastic sarcoma (adult t-cell lymphoma/leukaemia) (lukes-collins classification) stage i',
#  'malignant neoplasm of other specified sites of gallbladder and extrahepatic bile ducts localized',
#  'peptic ulcer, site unspec, unspec as acute or chronic, w/o mention of haemorrhage or perforation',
#  'deep necrosis of underlying tissues due to burn (deep third degree) of wrist, with loss of wrist',
#  'other and unspecified malignant neoplasms of lymphoid and histiocytic tissue inv pelvic lymph ns',
#  'deep necrosis of underlying tissues due to burn (deep third degree) of elbow, with loss of elbow',
#  'congenital or acquired abnormality of vagina, delivered, with mention of postpartum complication',
#  'malignant neoplasm of other specified sites of gallbladder and extrahepatic bile ducts recurrent',
#  'varicose veins of vulva and perineum complicating pregnancy and the puerperium, unspec as to eoc',
#  'open frac of vos with intcran inj of oth and unspec nature, with prolonged loc, w/o rtrn to pecl',
#  'obstruction caused by malposition of fetus at onset of labor, unspecified as to episode of care',
#  'diffuse mixed small and large cell lymphoma (peripheral t-cell lymphoma unspecified) refractory',
#  'erythema nodosum with hypersensitivity reaction in tuberculosis, confirmed by bacterial culture',
#  'extradural hem following inj, w/o ment of open intcran wound, with brief (less than 1 hour) loc',
#  'other named variants of lymphosarcoma and reticulosarcoma involving intra-abdominal lymph nodes',
#  'tuberculosis of thyroid gland, bacteriological or histological examination unknown (at present)',
#  'open fos or face with oth bones, w/o ment of intcran inj, with prolonged loc and return to pecl',
#  'superficial foreign body (splinter) of elbow, forearm, and wrist, w/o mow and w/o ment of infec',
#  'other spec indications for care or intervention related to labor and delivery, unspec as to eoc',
#  'burn (any degree) involving 90 percent or more of body surface with third degree burn of 20-29%',
#  'other specified chlamydial infection in conditions classified elsewhere and of unspecified site',
#  'infection and inflammatory reaction due to other internal prosthetic device, implant, and graft',
#  'traumatic amputation of arm and hand (complete) (partial), unilateral, below elbow, complicated',
#  'diffuse large cell lymphoma (angioimmunoblastic t-cell lymphoma) (working formulation) stage ii',
#  'clo fos or face with oth bones with subarac, sub/extradural hem, with prol loc and rtrn to pecl',
#  'hypertension secondary to renal disease, comp preg, childbirth, and the puerp, unspec as to eoc',
#  'longitudinal deficiency, combined, involving humerus, radius, and ulna (complete or incomplete)',
#  'recurrent unilateral or unspecified inguinal hernia, without mention of obstruction or gangrene',
#  'deep necro of under tiss due to burn (dtd) of unspec site of lower limb (leg), w/o ment of lobp',
#  'other specified bacterial infections in conditions classified elsewhere and of unspecified site',
#  'hereditary disease in family possibly affecting fetus, affecting manag of mother, with delivery',
#  'major depressive disorder, single episode, severe degree, without mention of psychotic behavior',
#  'deep necrosis of underlying tissues due to burn (deep third degree) of multiple specified sites',
#  'concussion with prolonged loss of consciousness, without return to pre-existing conscious level',
#  'other and unspec malignant neoplasms of lymphoid and histiocytic tissue, unspec extranodal site',
#  'suspec damage to fetus from oth disease in the mother, affect manag of mother, unspec as to eoc',
#  'unspecified condition involving the integument and temperature regulation of fetus and newborn.',
#  'other open skull fracture with cerebral laceration and contusion, with no loss of consciousness',
#  'breech or oth malpresentation successfully converted to cephalic presentation, unspec as to eoc',
#  'congenital or acquired abnormality of vulva, delivered, with mention of postpartum complication',
#  'tuberculosis of lung, nodular, bacteriological or histological examination unknown (at present)',
#  'subarachnoid subdural, and extradural haemorrhage following injury with open intracranial wound',
#  'multiple gestation with malpresentation of one fetus or more, unspecified as to episode of care',
#  'diffuse small cleaved cell lymphoma (intestinal t-cell lymphoma) (working formulation) stage iv',
#  'hypertension secondary to renal disease, complicating pregnancy, childbirth, and the puerperium',
#  't-immunoblastic lymphoma (peripheral t-cell lymphoma unspecified) (kiel classification) stage i',
#  'other umbilical cord complications during labor and delivery, unspecified as to episode of care',
#  'retracted nipple associated with childbirth, delivered, with mention of postpartum complication',
#  'other complications of obstetrical surgery and procedures, postpartum condition or complication',
#  'other and unspecified superficial injury of face, neck, and scalp, without mention of infection',
#  'obstetrical blood-clot embolism, with delivery, with or without mention of antepartum condition',
#  'unspecified complications of puerperium, with delivery, with mention of postpartum complication',
#  'deep necro of under tiss, burn (dtd) of eye (with oth parts of face, head, and neck), with lobp',
#  'unspecified venous complication, with delivery, with or without mention of antepartum condition',
#  'pulmonary complications of anesthesia or other sedation in labor and delivery, unspec as to eoc',
#  'twin pregnancy with fetal loss and retention of one fetus, antepartum condition or complication',
#  'intcran inj of oth and unspec nature, w/o ment of open intcran wound, with state of cons unspec',
#  'open frac of vos with intcran inj of oth and unspec nature, with prolonged loc and rtrn to pecl',
#  'open fos or face with oth bones, with intcran inj of oth and unspec nature, with concus, unspec',
#  'cns comps of anesthesia or other sedat labor and delivery, delivered, with men of postpart comp',
#  'congenital cardiovas disorders of mother, comp preg, childbirth, or the puerp, unspec as to eoc',
#  'osteoarthrosis, unspecified whether generalized or localized, involving pelvic region and thigh',
#  'burn (any degree) involving 90 percent or more of body surface with third degree burn of 10-19%',
#  'burn (any degree) involving 90 percent or more of body surface with third degree burn of 70-79%',
#  'intcran inj of oth and unspec nature, w/o ment of open intcran wound, prol loc and rtrn to pecl',
#  'oth and unspec cereb lacer and contu, w/o ment of open intcran wound, prol loc and rtrn to pecl',
#  'osteoarthrosis, localized, not specified whether primary or secondary, involving ankle and foot',
#  'other problems associated with amniotic cavity and membranes, unspecified as to episode of care',
#  'open fractures involving skull or face with other bones, with cerebral laceration and contusion',
#  'tuberculosis of other male genital organs, bacteriological or histological examination not done',
#  'other open skull fracture without mention of intracranial injury, with no loss of consciousness',
#  'other cardiovascular diseases of mother, with delivery, with mention of postpartum complication',
#  'burn (any degree) involving 90 percent or more of body surface with third degree burn of 50-59%',
# ...
#  'excessive foetal growth, affecting management of mother, unspecified as to episode of care',
#  'haematoma of spleen, without rupture of capsule, without mention of open wound into cavity',
#  'burn (any degree) involving 60-69 percent of body surface with third degree burn of 20-29%',
#  'diffuse small cleaved cell lymphoma (angiocentric lymphoma) (working formulation) stage ii',
#  'subarac hem following inj, w/o ment of open intcran wound, with prol loc, w/o rtrn to pecl',
#  'nonspecific abnormal findings on radiological and other examination of other sites of body',
#  'other and unspecified cord entanglement, with compression, complicating labor and delivery',
#  'burn (any degree) involving 40-49 percent of body surface with third degree burn of 40-49%',
#  'cerebellar or brain stem contu with open intcran wound, with state of consciousness unspec',
#  'burn (any degree) involving 60-69 percent of body surface with third degree burn of 50-59%',
#  'burn (any degree) involving 20-29 percent of body surface with third degree burn of 20-29%',
#  'tuberculosis of lung with cavitation, bacteriological or histological examination not done',
#  't-immunoblastic sarcoma (anaplastic large cell lymphoma t- and null-cell types) refractory',
#  'burn (any degree) involving 50-59 percent of body surface with third degree burn of 50-59%',
#  'malignant neoplasm of other and ill-defined sites within the lip, oral cavity, and pharynx',
#  'small cell cerebriform (mycosis fungoides sezary syndrome) (kiel classification) recurrent',
#  'superficial foreign body (splinter) of other, multiple, and unspec sites w/o mow, infected',
#  'burn (any degree) involving 80-89 percent of body surface with third degree burn of 30-39%',
#  'diffuse large cell lymphoma (diffuse large b-cell lymphoma) (working formulation) stage iv',
#  'superficial foreign body (splinter) of foot and toe(s), without major open wound, infected',
#  'breech or other malpresentation successfully converted to cephalic presentation, delivered',
#  'deep transverse arrest and persistent occipitoposterior position during labor and delivery',
#  'large b-cell lymphoma subtype primary mediastinal (thymic) large b-cell lymphoma recurrent',
#  'clo fos or face with oth bones, with oth and unspec intcran hem, with state of cons unspec',
#  'open fos or face with oth bones, with intcran inj of oth and unspec nature, with brief loc',
#  'closed frac of bos with oth and unspec intcran hem, with prolonged loc, w/o return to pecl',
#  'peptic ulcer unspecified as acute or chronic, without mention of hemorrhage or perforation',
#  'burn (any degree) involving 70-79 percent of body surface with third degree burn of 30-39%',
#  'tuberculosis of bronchus, tubercle bacilli not found in sputum , but found in bact culture',
#  'subdural hem following inj, w/o ment of open intcran wound, with prol loc and rtrn to pecl',
#  'other abnorm in shape or position of gravid uterus and of neighboring structures, antepart',
#  'other viral diseases of mother, comp pregnancy, childbirth, or the puerp, unspec as to eoc',
#  'osteoarthrosis, localized, not spec whether primary or secondary, involving oth spec sites',
#  'erythema due to burn (first degree) of multiple sites of upper limb, except wrist and hand',
#  'other specified miliary tuberculosis, bacteriological or histological examination not done',
#  'burn (any degree) involving 70-79 percent of body surface with third degree burn of 70-79%',
#  'deep necrosis of underlying tissues due to burn (deep third degree) of face, head and neck',
#  'burn (any degree) involving 70-79 percent of body surface with third degree burn of 20-29%',
#  'moderate or severe vision impairment, better eye; profound vision impairment of lesser eye',
#  'subarac hem following inj, with open intcran wound, with prolonged loc, w/o return to pecl',
#  'small noncleaved follicular center cell lymphoma (high grade b-cell burkitt-like lymphoma)',
#  'illegally induced abortion, unspecified, complicated by genital tract and pelvic infection',
#  'osteoarthrosis, localized, not specified whether primary or secondary, involving upper arm',
#  'burn (any degree) involving 40-49 percent of body surface with third degree burn of 20-29%',
#  'illegally induced abortion, unspecified, complicated by damage to pelvic organs or tissues',
#  'cerebellar or brain stem contu w/o ment of open intcran wound, with loc of unspec duration',
#  'burn (any degree) involving 70-79 percent of body surface with third degree burn of 50-59%',
#  'cerebellar or brain stem lacer with open intcran wound, with state of consciousness unspec',
#  'burn (any degree) involving 30-39 percent of body surface with third degree burn of 20-29%',
#  'cerebellar or brain stem lacer w/o ment of open intcran wound, with loc of unspec duration',
#  'closed frac of vos with subarac, sub/extradural hem, with prolonged loc and return to pecl',
#  'major abnormality of bony pelvis, not further specified, unspecified as to episode of care',
#  'burn (any degree) involving 30-39 percent of body surface with third degree burn of 10-19%',
#  'oth and unspec cerebral lacer and contu, w/o ment of open intcran wound, with moderate loc',
#  'burn (any degree) involving 80-89 percent of body surface with third degree burn of 70-79%',
#  'burn (any degree) involving 80-89 percent of body surface with third degree burn of 20-29%',
#  'other venous complications, with delivery, with or without mention of antepartum condition',
#  'burn (any degree) involving 30-39 percent of body surface with third degree burn of 30-39%',
#  'cortex (cerebral) lacer w/o ment of open intcran wound, with state of consciousness unspec',
#  'suspected damage to fetus from other disease in the mother, affecting management of mother',
#  'burn (any degree) involving 10-19 percent of body surface with third degree burn of 10-19%',
#  'tuberculous encephalitis or myelitis, bacteriological or histological examination not done',
#  'sensitivity, shyness, and social withdrawal disorder specific to childhood and adolescence',
#  'burn (any degree) involving 40-49 percent of body surface with third degree burn of 30-39%',
#  'full-thickness skin loss due to burn (tdn) of two or more digits of hand, not includ thumb',
#  'closed frac of vos with oth and unspec intcran hem, with prolonged loc, w/o return to pecl',
#  "arthropathy, site unspecified, associated with reiter's disease and nonspecific urethritis",
#  'oth open skull frac with oth and unspec intcran hem, with prolonged loc and return to pecl',
#  'deep necro of under tiss due to burn (dtd) of single digit oth than thumb, w/o ment of lof',
#  'multiple open fractures involving both upper limbs, and upper limb with rib(s) and sternum',
#  'burn (any degree) involving 80-89 percent of body surface with third degree burn of 40-49%',
#  'concussion with prolonged loss of consciousness and return to pre-existing conscious level',
#  'other specified orchitis, epididymitis, and epididymo-orchitis, without mention of abscess',
#  'burn (any degree) involving 70-79 percent of body surface with third degree burn of 40-49%',
#  'burn (any degree) involving 70-79 percent of body surface with third degree burn of 60-69%',
#  'small cell cerebriform (mycosis fungoides sezary syndrome) (kiel classification) stage iii',
#  'disturbance of emotions specific to childhood and adolescence with anxiety and fearfulness',
#  'burn (any degree) involving 70-79 percent of body surface with third degree burn of 10-19%',
#  'traumatic ampu of arm and hand (complete) (partial), unilat, below elbow, w/o ment of comp',
#  'tuberculosis of bronchus, bacteriological or histological examination unknown (at present)',
#  'tuberculous pneumothorax, bacteriological or histological examination unknown (at present)',
#  'oth closed skull frac with subarac, sub/extradural hem, with state of consciousness unspec',
#  'bipolar affective disorder, depressed, severe degree, specified as with psychotic behavior',
#  'burn (any degree) involving 60-69 percent of body surface with third degree burn of 30-39%',
#  'extragonadal primary germ cell tumor mixed incl yolk sac tumor and choriocarcinoma stage i',
#  'oth malpres, malpos, and disproportion during labor and delivery affecting fetus or n/born',
#  'burn (any degree) involving 20-29 percent of body surface with third degree burn of 10-19%',
#  'oth open skull frac with intcran inj of oth and unspec nature, with loc of unspec duration',
#  'burn (any degree) involving 80-89 percent of body surface with third degree burn of 80-89%',
#  'human papilloma virus infection in conditions classified elsewhere and of unspecified site',
#  'major abnormality of bony pelvis, not further specified, in pregnancy, labor, and delivery',
#  'diffuse large cell lymphoma (diffuse large b-cell lymphoma) (working formulation) stage ii',
#  'other spec infectious and parasitic diseases comp pregnancy, childbirth, or the puerperium',
#  'chronic or unspecified peptic ulcer of unspecified site with perforation, with obstruction',
#  'other abnorm in shape or position of gravid uterus and of neighboring structures, postpart',
#  'diffuse small cleaved cell lymphoma (adult t-cell lymphoma/leukemia) (working formulation)',
#  'clo fos or face with oth bones with subarac, sub/extradural hem, with state of cons unspec',
#  'central nervous system complications of anesthesia or other sedation in labor and delivery',
#  'unspecified infection or infestation complicating pregnancy, childbirth, or the puerperium',
#  'partial epilepsy, without mention of impairment of consciousness with intractable epilepsy',
#  'erythema nodosum with hypersensitivity reaction in tuberculosis, bact or hist exam unknown',
#  'small cleaved cell diffuse or nodular rarely diffuse mixed or large cleaved cell stage iii',
#  'oth closed skull frac with intcran inj of oth and unspec nature, with state of cons unspec',
#  'oth and unspec intcran hem following inj, with open intcran wound, with concussion, unspec',
#  'subdural hem following inj, with open intcran wound, with prolonged loc and return to pecl',
#  'tuberculosis of other urinary organs, bacteriological or histological examination not done',
#  'lymphoblastic lymphoma (precursor t-lymphoblastic lymphoma/leukaemia) (working formulation',
#  'burn (any degree) involving 80-89 percent of body surface with third degree burn of 50-59%',
#  'shock during or following labor and delivery, with delivery, with mention of postpart comp',
#  'large b-cell lymphoma subtype primary mediastinal (thymic) large b-cell lymphoma stage iii',
#  'tuberculosis of other specified bone, bacteriological or histological examination not done',
#  'full-thickness skin loss due to burn (third degree nos) of multiple sites of lower limb(s)',
#  'burn (any degree) involving 90 percent or more of body surface burn (any degree) involving',
#  'diffuse mixed small and large cell lymphoma (nodal marginal zone b-cell lymphoma) stage iv',
#  'chronic gastrojejunal ulcer without mention of hemorrhage or perforation, with obstruction',
#  'closed frac of bos with subarac, sub/extradural hem, with prolonged loc and return to pecl',
#  'blisters with epidermal loss due to burn (second degree) of unspecified site of upper limb',
#  'suspected damage to fetus from viral disease in the mother, affecting management of mother',
#  'osteoarthrosis, localized, not specified whether primary or secondary, involving lower leg',
#  'burn (any degree) involving 40-49 percent of body surface with third degree burn of 10-19%',
#  'deep necro of under tiss due to burn (dtd) of scapular region, w/o ment of loss of scapula',
#  'burn (any degree) involving 80-89 percent of body surface with third degree burn of 60-69%',
#  'insect bite, nonvenomous of face, neck, and scalp except eye, without mention of infection',
#  'diffuse mixed small and large cell lymphoma (angioimmunoblastic t-cell lymphoma) recurrent',
#  'small cleaved cell diffuse or nodular rarely diffuse mixed or large cleaved cell recurrent',
#  'open frac of bos with intcran inj of oth and unspec nature, with prol loc and rtrn to pecl',
#  'burn (any degree) involving 50-59 percent of body surface with third degree burn of 10-19%',
#  'burn (any degree) involving 60-69 percent of body surface with third degree burn of 10-19%',
#  'burn (any degree) involving 50-59 percent of body surface with third degree burn of 40-49%',
#  'diffuse large cell lymphoma (adult t-cell lymphoma/leukemia) (working formulation) stage i',
#  'unspecified complication of anesthesia or other sedation in labor and delivery, antepartum',
#  'diffuse mixed small and large cell lymphoma (nodal marginal zone b-cell lymphoma) stage ii',
#  'large cell immunoblastic lymphoma (angiocentric lymphoma) (working formulation) refractory',
#  'other specified respiratory tuberculosis, tubercle bacilli found (in sputum) by microscopy',
#  'chronic or unspecified gastrojejunal ulcer with hemorrhage, without mention of obstruction',
#  'diffuse small cleaved cell lymphoma (angiocentric lymphoma) (working formulation) stage iv',
#  'burn (any degree) involving 80-89 percent of body surface with third degree burn of 10-19%',
#  'burn (any degree) involving 60-69 percent of body surface with third degree burn of 60-69%',
#  'diffuse large cell lymphoma (peripheral t-cell lymphoma unspecified) (working formulation)',
#  'diffuse mixed small and large cell lymphoma (angioimmunoblastic t-cell lymphoma) stage iii',
#  'burn (any degree) involving 60-69 percent of body surface with third degree burn of 40-49%',
#  "hodgkin's disease, lymphocytic-histiocytic predominance involving intrapelvic lymph nodes.",
#  'other specified viral infection in conditions classified elsewhere and of unspecified site',
#  'cerebral autosomal dominant arteriopathy with subcortical infarcts and leukoencephalopathy',
#  'rupture of uterus during labor, delivered, with or without mention of antepartum condition',
#  'deep necro of under tiss due to burn (dtd) of upper limb, except wrist and hand, with lobp',
#  'diffuse mixed small and large cell lymphoma (nodal marginal zone b-cell lymphoma) stage i',
#  'unspecified disorder of lactation, with delivery, with mention of postpartum complication',
#  'diffuse large cell lymphoma (intestinal t-cell lymphoma) (working formulation) refractory',
#  'subarac hem following inj, w/o ment of open intcran wound, with prol loc and rtrn to pecl',
#  't-immunoblastic sarcoma (anaplastic large cell lymphoma t- and null-cell types) stage iii',
#  'closed fracture of base of skull with intracranial injury of other and unspecified nature',
#  't-immunoblastic sarcoma (anaplastic large cell lymphoma t- and null-cell types) recurrent',
#  'tuberculosis of bladder, bacteriological or histological examination unknown (at present)',
#  'cns complications of anesthesia or other sedation in labor and delivery, unspec as to eoc',
#  'illegally induced abortion, incomplete, complicated by damage to pelvic organs or tissues',
#  'large b-cell lymphoma subtype primary mediastinal (thymic) large b-cell lymphoma stage ii',
#  'infection and inflammatory reaction due to other genitourinary device, implant, and graft',
#  'small cleaved cell diffuse or nodular rarely diffuse mixed or large cleaved cell stage iv',
#  'erythema nodosum with hypersensitivity reaction in tuberculosis, confirmed histologically',
#  'deep necro of under tiss due to burn (dtd) of forehead and cheek, w/o ment of loss of f&c',
#  'complications of the administration of anesthetic or other sedation in labor and delivery',
#  'open fos or face with oth bones with subarac, sub/extradural hem, with concussion, unspec',
#  'extradural hem following inj, w/o ment of open intcran wound, with loc of unspec duration',
#  'deep necro of under tiss due to burn (dtd) of scalp (any part), w/o ment of loss of scalp',
#  'sensitivity, shyness, and social withdrawal disorder specific to childhood or adolescence',
#  'specified congenital anomalies of anterior chamber, chamber angle, and related structures',
#  'small cell cerebriform (mycosis fungoides sezary syndrome) (kiel classification) stage ii',
#  ...]

# %%
finalDF = []

name_DRUG ='DRUG'
name_Indication = 'INDICATIONS'

for i in range (len(clean_Text)):
    
#     print("+++++++++++++++")
    lenp = []
    text_dict = [{'entities':[] }]
    ext_text = clean_Text[i]
    original_text =  ext_text 
    lenp.append(original_text)
    
    for i in drugList:
        try: 
            
            a = re.finditer(r'\b({0})'.format(re.escape(i)),ext_text,re.IGNORECASE)
            
            for match in a: 
                
                s = match.start()
                e = match.end()
        
                DRUG_lst = []
                DRUG_lst.append(match.start())
                DRUG_lst.append(match.end())
                DRUG_lst.append(name_DRUG)
                DRUG_tup = tuple(DRUG_lst)

                
                text_dict[0]['entities'].append(DRUG_tup)

                ext_text = ext_text.replace(ext_text[s:e], ' '*len(ext_text[s:e]),1)
                          
        except Exception as el:
            print('Handling run-time error:')
            print('Failed at last: {}'.format(str(el)))
            traceback.print_exc()
            
    for i in indicationList:
        try: 
            
            a = re.finditer(r'\b({0}\b)'.format(re.escape(i)),ext_text,re.IGNORECASE)
            
            for match in a: 
                
                s = match.start()
                e = match.end()
    #             print('Found "%s" at %d:%d' % (ext_text[s:e], s, e))
        
                DRUG_lst = []
                DRUG_lst.append(match.start())
                DRUG_lst.append(match.end())
                DRUG_lst.append(name_Indication)
                DRUG_tup = tuple(DRUG_lst)
                
                text_dict[0]['entities'].append(DRUG_tup)
#                 print(ext_text[s:e])

                ext_text = ext_text.replace(ext_text[s:e], ' '*len(ext_text[s:e]),1)
                          
        except Exception as el:
            print('Handling run-time error:')
            print('Failed at last: {}'.format(str(el)))
            traceback.print_exc()


    lenp.append(text_dict[0])
    finalDF.append(tuple(lenp))

# %%
finalDF[:2]
# Out:
# [('1 1.1 Infections of the Ear, Nose, and ThroatAmoxicillin capsules are indicated in the treatment of infections due to susceptible (ONLY ss-lactamase-negative) isolates of Streptococcus species. (a- and   ss-hemolytic isolates only), Streptococcus pneumoniae, Staphylococcus spp., or Haemophilus influenzae. 1.2 Infections of the Genitourinary TractAmoxicillin capsules are indicated in the treatment of infections due to susceptible (ONLY ss-lactamase-negative) isolates of Escherichia coli, Proteus mirabilis, or Enterococcus faecalis. 1.3 Infections of the Skin and Skin StructureAmoxicillin capsules are indicated in the treatment of infections due to susceptible (ONLY ss-lactamase-negative) isolates of Streptococcus spp. (a- and ss-hemolytic isolates only), Staphylococcus spp., or E. coli. 1.4 Infections of the Lower Respiratory TractAmoxicillin capsules are indicated in the treatment of infections due to susceptible (ONLY ss-lactamase-negative) isolates of Streptococcus spp. (a- and ss-hemolytic isolates only), S. pneumoniae, Staphylococcus spp., or H. influenzae. 1.5 Helicobacter pylori Infection Triple therapy for Helicobacter pylori with clarithromycin and lansoprazole: Amoxicillin capsules in combination with clarithromycin plus lansoprazole as triple therapy, is indicated for the treatment of patients with H. pylori infection and duodenal ulcer disease (active or 1-year history of a duodenal ulcer) to eradicate H. pylori. Eradication of H. pylori has been shown to reduce the risk of duodenal ulcer recurrence. Dual therapy for H. pylori with lansoprazole : Amoxicillin capsules, in combination with lansoprazole delayed-release capsules as dual therapy, is indicated for the treatment of patients with H. pylori infection and duodenal ulcer disease (active or 1-year history of a duodenal ulcer) who are either allergic or intolerant to clarithromycin or in whom resistance to clarithromycin is known or suspected. (See the clarithromycin package insert, MICROBIOLOGY.) Eradication of H. pylori has been shown to reduce the risk of duodenal ulcer recurrence. 1.6 UsageTo reduce the development of drug-resistant bacteria and maintain the effectiveness of amoxicillin capsules and other antibacterial drugs, amoxicillin capsules should be used only to treat infections that are proven or strongly suspected to be caused by bacteria. When culture and susceptibility information are available, they should be considered in selecting or modifying antibacterial therapy. In the absence of such data, local epidemiology and susceptibility patterns may contribute to the empiric selection of therapy. ',
#   {'entities': [(474, 490, 'DRUG'),
#     (1156, 1170, 'DRUG'),
#     (1230, 1244, 'DRUG'),
#     (1864, 1878, 'DRUG'),
#     (1904, 1918, 'DRUG'),
#     (1951, 1965, 'DRUG'),
#     (1175, 1187, 'DRUG'),
#     (1250, 1262, 'DRUG'),
#     (1569, 1581, 'DRUG'),
#     (1626, 1638, 'DRUG'),
#     (1189, 1200, 'DRUG'),
#     (1584, 1595, 'DRUG'),
#     (2182, 2193, 'DRUG'),
#     (2234, 2245, 'DRUG'),
#     (492, 499, 'DRUG'),
#     (1082, 1111, 'INDICATIONS'),
#     (1354, 1368, 'INDICATIONS'),
#     (1408, 1422, 'INDICATIONS'),
#     (1510, 1524, 'INDICATIONS'),
#     (1753, 1767, 'INDICATIONS'),
#     (1807, 1821, 'INDICATIONS'),
#     (2059, 2073, 'INDICATIONS'),
#     (1850, 1860, 'INDICATIONS'),
#     (1340, 1349, 'INDICATIONS'),
#     (1739, 1748, 'INDICATIONS')]}),
#  ('1 Therapy with lipid-altering agents should be only one component of multiple risk factor intervention in individuals at significantly increased risk for atherosclerotic vascular disease due to hypercholesterolemia. Drug therapy is recommended as an adjunct to diet when the response to a diet restricted in saturated fat and cholesterol and other nonpharmacologic measures alone has been inadequate. In patients with CHD or multiple risk factors for CHD, atorvastatin calcium tablets can be started simultaneously with diet.1.1 Prevention of Cardiovascular Disease in AdultsIn adult patients without clinically evident coronary heart disease, but with multiple risk factors for coronary heart disease such as age, smoking, hypertension, low HDL-C, or a family history of early coronary heart disease, atorvastatin calcium tablets are indicated to:*Reduce the risk of myocardial infarction *Reduce the risk of stroke *Reduce the risk for revascularization procedures and angina In adult patients with type 2 diabetes, and without clinically evident coronary heart disease, but with multiple risk factors for coronary heart disease such as retinopathy, albuminuria, smoking, or hypertension, atorvastatin calcium tablets are indicated to:*Reduce the risk of myocardial infarction *Reduce the risk of stroke In adult patients with clinically evident coronary heart disease, atorvastatin calcium tablets are indicated to:*Reduce the risk of non-fatal myocardial infarction *Reduce the risk of fatal and non-fatal stroke *Reduce the risk for revascularization procedures *Reduce the risk of hospitalization for CHF *Reduce the risk of angina 1.2 HyperlipidemiaAtorvastatin calcium tablets are indicated*As an adjunct to diet to reduce elevated total-C, LDL-C, apo B, and TG levels and to increase HDL-C in adult patients with primary hypercholesterolemia (heterozygous familial and nonfamilial) and mixed dyslipidemia ( Fredrickson Types IIa and IIb); *As an adjunct to diet for the treatment of adult patients with elevated serum TG levels ( Fredrickson Type IV); *For the treatment of adult patients with primary dysbetalipoproteinemia ( Fredrickson Type III) who do not respond adequately to diet; *To reduce total-C and LDL-C in patients with homozygous familial hypercholesterolemia (HoFH) as an adjunct to other lipid-lowering treatments (e.g., LDL apheresis) or if such treatments are unavailable;*As an adjunct to diet to reduce total-C, LDL-C, and apo B levels in pediatric patients, 10 to 17 years of age, with heterozygous familial hypercholesterolemia (HeFH) if after an adequate trial of diet therapy the following findings are present: \t *LDL-C remains = 190 mg/dL or*LDL-C remains = 160 mg/dL and:*there is a positive family history of premature cardiovascular disease or*two or more other CVD risk factors are present in the pediatric patient1.3 Limitations of UseAtorvastatin calcium tablets have not been studied in conditions where the major lipoprotein abnormality is elevation of chylomicrons ( Fredrickson Types I and V). ',
#   {'entities': [(456, 476, 'DRUG'),
#     (802, 822, 'DRUG'),
#     (1191, 1211, 'DRUG'),
#     (1372, 1392, 'DRUG'),
#     (326, 337, 'DRUG'),
#     (2517, 2559, 'INDICATIONS'),
#     (2243, 2283, 'INDICATIONS'),
#     (1822, 1850, 'INDICATIONS'),
#     (2111, 2133, 'INDICATIONS'),
#     (620, 642, 'INDICATIONS'),
#     (679, 701, 'INDICATIONS'),
#     (778, 800, 'INDICATIONS'),
#     (1049, 1071, 'INDICATIONS'),
#     (1108, 1130, 'INDICATIONS'),
#     (1348, 1370, 'INDICATIONS'),
#     (868, 889, 'INDICATIONS'),
#     (1257, 1278, 'INDICATIONS'),
#     (1448, 1469, 'INDICATIONS'),
#     (1587, 1602, 'INDICATIONS'),
#     (2347, 2360, 'INDICATIONS'),
#     (2997, 3009, 'INDICATIONS'),
#     (1901, 1913, 'INDICATIONS'),
#     (216, 228, 'INDICATIONS'),
#     (724, 736, 'INDICATIONS'),
#     (1177, 1189, 'INDICATIONS'),
#     (326, 337, 'INDICATIONS'),
#     (1152, 1163, 'INDICATIONS'),
#     (1139, 1150, 'INDICATIONS'),
#     (529, 539, 'INDICATIONS'),
#     (1008, 1016, 'INDICATIONS'),
#     (1669, 1676, 'INDICATIONS'),
#     (2889, 2896, 'INDICATIONS'),
#     (738, 745, 'INDICATIONS'),
#     (971, 977, 'INDICATIONS'),
#     (1631, 1637, 'INDICATIONS'),
#     (910, 916, 'INDICATIONS'),
#     (1299, 1305, 'INDICATIONS'),
#     (1510, 1516, 'INDICATIONS'),
#     (194, 199, 'INDICATIONS'),
#     (1756, 1761, 'INDICATIONS'),
#     (2453, 2458, 'INDICATIONS'),
#     (1607, 1610, 'INDICATIONS'),
#     (1749, 1752, 'INDICATIONS'),
#     (2220, 2223, 'INDICATIONS'),
#     (2442, 2445, 'INDICATIONS'),
#     (2649, 2652, 'INDICATIONS'),
#     (2678, 2681, 'INDICATIONS'),
#     (1793, 1796, 'INDICATIONS'),
#     (1767, 1769, 'INDICATIONS'),
#     (2027, 2029, 'INDICATIONS')]})]

# %%
type(finalDF)
# Out:
# list

# %%
textfile = open("/Users/souravsingh/Documents/NER/Annotation_Data/annotated.txt", "w")
for element in finalDF:
#     print(element)    
    textfile.write('{}'.format(element))
textfile.close()

# %%
# drugList.index('macrocrystals')

# %%
# !python -m spacy download en_core_med7_lg

# %%
import spacy
from spacy.lang.en import English
import en_core_med7_lg

# %%
# !python -m spacy download en_core_web_md

# %%
# nlp = spacy.load('en_core_web_md')
nlp = spacy.load('en_core_med7_lg')

# %%
nlp.pipe_names

# %%
doc =nlp('Google and facebook are in USA')

# %%
for ent in doc.ents:
    print(ent.text,ent.start_char,ent.end_char,ent.label_)

# %%
ner= nlp.get_pipe("ner")

# %%
train_data = finalDF

# %%
for text,annotation in train_data:
    for ent in annotation.get('entities'):
        ner.add_label(ent[2])

# %%
ner.labels

# %%
disable_pipes =[pipe for pipe in nlp.pipe_names if pipe != 'ner']

# %%
import random
from spacy.util import minibatch, compounding
from spacy import displacy
from pathlib import Path

# %%
from spacy.training.example import Example

# %%
lst= []
with nlp.disable_pipes(*disable_pipes):
        optimizer = nlp.resume_training()
        
        for itr in range(400):
            
            try:
  
                random.shuffle(train_data) # shuffle the training data before each iteration
                losses = {}
                batches = minibatch(train_data, size = compounding(1.0, 4.0, 1.001))

                for batch in batches:
                    
                    text, annotations = zip(*batch)
                    
                    example = []
                    # Update the model with iterating each text
                    for i in range(len(text)):
                        doc = nlp.make_doc(text[i])
                        example.append(Example.from_dict(doc, annotations[i]))

                    nlp.update(          
#                         text,
#                         annotations,
                        example,
                        drop = 0.5,  
                        sgd = optimizer,
                        losses = losses)

                    print('=======================================')
                    print('Interation = '+str(itr))
                    print('Losses = '+str(losses))
            
            except ValueError as ve:
                print("value error")
                print(ve)
                lst.append(ve)
#                 print(texts)
#                 break

# %%
col_dict = {}
seven_colours = ['#e6194B', '#3cb44b', '#46E7E9', '#ffd8b1', '#f58231', '#f032e6', '#42d4f4']
for label, colour in zip(nlp.pipe_labels['ner'], seven_colours):
    col_dict[label] = colour

options = {'ents': nlp.pipe_labels['ner'], 'colors':col_dict}

# %%
ner.to_disk("/Users/souravsingh/Documents/NER/model")

# %%
doc= nlp('''Nitrofurantoin monohydrate/macrocrystals capsules are indicated only for the treatment of acute uncomplicated urinary tract infections (acute cystitis) caused by susceptible strains of Escherichia coli or Staphylococcus saprophyticus.Nitrofurantoin is not indicated for the treatment of pyelonephritis or perinephric abscesses.To reduce the development of drug-resistant bacteria and maintain the effectiveness of nitrofurantoin monohydrate/macrocrystals capsules and other antibacterial drugs, nitrofurantoin monohydrate/macrocrystals capsules should be used only to treat or prevent infections that are proven or strongly suspected to be caused by susceptible bacteria. When culture and susceptibility information are available, they should be considered in selecting or modifying antibacterial therapy. In the absence of such data, local epidemiology and susceptibility patterns may contribute to the empiric selection of therapy.Nitrofurantoins lack the broader tissue distribution of other therapeutic agents approved for urinary tract infections. Consequently, many patients who are treated with nitrofurantoin monohydrate/macrocrystals capsules are predisposed to persistence or reappearance of bacteriuria. (See CLINICAL STUDIES.) Urine specimens for culture and susceptibility testing should be obtained before and after completion of therapy. If persistence or reappearance of bacteriuria occurs after treatment with nitrofurantoin monohydrate/macrocrystals capsules, other therapeutic agents with broader tissue distribution should be selected. In considering the use of nitrofurantoin monohydrate/macrocrystals capsules, lower eradication rates should be balanced against the increased potential for systemic toxicity and for the development of antimicrobial resistance when agents with broader tissue distribution are utilized.''')

# %%
# doc =nlp ('''KEYTRUDA is a prescription medicine used to treat  a kind of skin cancer called melanoma. KEYTRUDA may be used .when your melanoma has spread or cannot be removed by surgery (advanced melanoma), or to help prevent melanoma from coming back after it and lymph nodes that contain cancer have been removed by surgery a kind of lung cancer called non-small cell lung cancer (NSCLC)''')

# %%
doc = nlp('''Eletriptan hydrobromide tablets are indicated for the acute treatment of migraine with or without aura in adults.Limitations of Use: •Use only if a clear diagnosis of migraine has been established. If a patient has no response to the first migraine attack treated with eletriptan hydrobromide tablets, reconsider the diagnosis of migraine before eletriptan hydrobromide tablets are administered to treat any subsequent attacks.•Eletriptan hydrobromide tablets are not intended for the prevention of migraine attacks.•Safety and effectiveness of eletriptan hydrobromide tablets have not been established for cluster headache.''')

# %%
doc
# Out:
# Eletriptan hydrobromide tablets are indicated for the acute treatment of migraine with or without aura in adults.Limitations of Use: •Use only if a clear diagnosis of migraine has been established. If a patient has no response to the first migraine attack treated with eletriptan hydrobromide tablets, reconsider the diagnosis of migraine before eletriptan hydrobromide tablets are administered to treat any subsequent attacks.•Eletriptan hydrobromide tablets are not intended for the prevention of migraine attacks.•Safety and effectiveness of eletriptan hydrobromide tablets have not been established for cluster headache.

# %%
for ent in doc.ents:
    print(ent.text,ent.start_char,ent.end_char,ent.label_)
# Out:
# Eletriptan hydrobromide 0 23 DRUG
# migraine 73 81 INDICATIONS
# aura 98 102 INDICATIONS
# migraine 167 175 INDICATIONS
# migraine 240 248 INDICATIONS
# eletriptan hydrobromide 269 292 DRUG
# migraine 330 338 INDICATIONS
# eletriptan hydrobromide 346 369 DRUG
# prevention 485 495 INDICATIONS
# migraine 499 507 INDICATIONS
# eletriptan hydrobromide 545 568 DRUG
# cluster headache 607 623 INDICATIONS

# %%
col_dict = {}
seven_colours = ['#e6194B', '#3cb44b', '#ffe119', '#ffd8b1', '#f58231', '#f032e6', '#46e99a']
for label, colour in zip(nlp.pipe_labels['ner'], seven_colours):
    col_dict[label] = colour

options = {'ents': nlp.pipe_labels['ner'], 'colors':col_dict}

# %%
spacy.displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ffe119; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eletriptan hydrobromide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  tablets are indicated for the acute treatment of
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     migraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDICATIONS</span>
# </mark>
#  with or without
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aura
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDICATIONS</span>
# </mark>
#  in adults.Limitations of Use: •Use only if a clear diagnosis of
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     migraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDICATIONS</span>
# </mark>
#  has been established. If a patient has no response to the first
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     migraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDICATIONS</span>
# </mark>
#  attack treated with
# <mark class="entity" style="background: #ffe119; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eletriptan hydrobromide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  tablets, reconsider the diagnosis of
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     migraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDICATIONS</span>
# </mark>
#  before
# <mark class="entity" style="background: #ffe119; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eletriptan hydrobromide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  tablets are administered to treat any subsequent attacks.•Eletriptan hydrobromide tablets are not intended for the
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prevention
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDICATIONS</span>
# </mark>
#  of
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     migraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDICATIONS</span>
# </mark>
#  attacks.•Safety and effectiveness of
# <mark class="entity" style="background: #ffe119; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eletriptan hydrobromide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  tablets have not been established for
# <mark class="entity" style="background: #42d4f4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cluster headache
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INDICATIONS</span>
# </mark>
# .</div></span>

# %%
#Urine, culture
indicationList.index('urine')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-a077985d40bc> in <module>
#       1 #Urine, culture
# ----> 2 indicationList.index('urine')
#
# ValueError: 'urine' is not in list

# %%
drugList.index('eletriptan hydrobromide')
# Out:
# 1957

# %%
print(len(indicationList))
print(len(drugList))
# Out:
# 84316
# 7303
